# %%
addprocs()
@show workers()
using BenchmarkTools, Compat
using BigArrays, GSDicts, S3Dicts, BigArrays.BinDicts
using OffsetArrays
using Plots


ba = BigArray(S3Dict("s3://neuroglancer/s1_v1/image/6_6_30/"))
#const img = ba[4097:4096+1024, 4097:4096+1024, 1025:1024+512]
const img = ba[4097:4096+512, 4097:4096+512, 1025:1024+512] |> parent
#using HDF5
#rm("/tmp/img.h5")
#h5write("/tmp/img.h5", "image", img);
# Out:
# nworkers() = 12
# INFO: Recompiling stale cache file /usr/people/jingpeng/.julia/lib/v0.6/GSDicts.ji for module GSDicts.
# 	From worker 7:	From worker 7: processing block in global range: 4096-4608_4096-4608_1024-1088
# 	From worker 2:	From worker 2: processing block in global range: 4096-4608_4096-4608_1088-1152
# 	From worker 3:	From worker 3: processing block in global range: 4096-4608_4096-4608_1152-1216
# 	From worker 5:	From worker 5: processing block in global range: 4096-4608_4096-4608_1216-1280
# 	From worker 4:	From worker 4: processing block in global range: 4096-4608_4096-4608_1280-1344
# 	From worker 6:	From worker 6: processing block in global range: 4096-4608_4096-4608_1344-1408
# 	From worker 9:	From worker 9: processing block in global range: 4096-4608_4096-4608_1408-1472
# 	From worker 8:	From worker 8: processing block in global range: 4096-4608_4096-4608_1472-1536
# cutout speed: 11.023721257590358 MB/s

# %%
using DataFrames

# prepare directory
tempDir = tempname()
const KEY = "6_6_30"
const infoPath = joinpath(tempDir,"info")
const datasetDir = joinpath(tempDir, "6_6_30")
mkdir(tempDir)
mkdir(datasetDir)
const CHUNK_SIZE = [256,256,32]
const TASK_NUM = 20 
const TEST_NUM = 3

function save(ba::BigArray, img)
    sz = size(img)
    t1 = time()
    ba[1:sz[1], 1:sz[2], 1:sz[3]] = img
    time()-t1
end 

function cutout(ba::BigArray, sz)
    t1 = time()
    ba[1:sz[1], 1:sz[2], 1:sz[3]]
    time()-t1
end 

function test(ba::BigArray, img; testTime = 5)
    tsList = Vector()
    tcList = Vector()
    for i in 1:TEST_NUM
        push!(tsList, save(ba, img))
        push!(tcList, cutout(ba, size(img)))
    end
    totalSize = length(img)*sizeof(eltype(img)) / 1000/1000
    totalSize / median(tsList), totalSize / median(tcList)
end 

function run_trials(chunkSize; testTime=5)
    sz = size(img)
    dataSize = length(img) * sizeof(eltype(img)) / 1000 / 1000 # MB
    infoString = """
{"num_channels": 1, "type": "image", "data_type": "uint8", "scales": [
{"encoding": "raw", "chunk_sizes": [$(chunkSize)], "key": "$(KEY)", "resolution": [6, 6, 30], "voxel_offset": [0, 0, 0], "size": [12286, 11262, 2046]}
]} 
"""
    open( infoPath, "w" ) do f
        write(f, infoString)
    end 
    gsDir = "gs://seunglab/jpwu/benchmark/image"
    s3Dir = "s3://seunglab/jpwu/benchmark/image"
    #run(`gsutil cp $(infoPath) $(joinpath(gsDir, "info"))`)
    #run(`gsutil cp $(infoPath) $(joinpath(s3Dir, "info"))`)
    
    #df = DataFrame(storage = ["Local", "GS", "S3"], task_num=20, chunk_size=chunkSize)
    
    # test local speed
    ba_local = BigArray(BinDict(datasetDir))
    ss,sc = test(ba_local, img; testTime=testTime)
    
    # test GS speed
    
    #ba_gs = BigArray(GSDict(joinpath(gsDir, KEY)); taskNum=taskNum)
    #ts_gs, tc_gs = test(ba_gs, img)
    
    # test S3 speed
    #ba_s3 = BigArray(GSDict(joinpath(gsDir, KEY)); taskNum=taskNum)
    #ts_s3, tc_s3 = test(ba_s3, img)
    
    #df[:save_speed] = ts_local#[ts_local, ts_gs, ts_s3]
    #df[:cutout_speed] = tc_local#[tc_local, tc_gs, tc_s3]
    #@show df
    return ss, sc
end
# Out:
# WARNING: redefining constant KEY
# WARNING: redefining constant infoPath
# WARNING: redefining constant datasetDir
# WARNING: redefining constant CHUNK_SIZE
# run_trials (generic function with 1 method)

# %%
# taskNumList = [1, 5, 10, 15, 20, 25, 30]
# #taskNumList = [1, 10, 20]
# ss_list = Vector()
# sc_list = Vector()
# for taskNum in taskNumList
#     @show taskNum
#     ss, sc = run_trials(CHUNK_SIZE, taskNum; testTime=7)
#     push!(ss_list, ss)
#     push!(sc_list, sc)
# end 

# using Plots
# plot(taskNumList, hcat(ss_list, sc_list))
# #plot(taskNumList, ss_list)

# %%
# #plotly()
# gr()
# #pyplot()
# #plot(taskNumList, ss_list)
# plot(taskNumList, hcat(ss_list, sc_list), m=(8,:auto), legend=true,
#         lab=["saving", "cutout"],
#         xlabel="task number", 
#         ylabel="speed (MB/s)")

# %%
chunkSizeList = [[256,256,1], [256,256,8], [256,256,16], [256,256,32], [256,256,64], [256,256,128], [256,256,256]]

ss_list2 = Vector()
sc_list2 = Vector()
for chunkSize in chunkSizeList
    @show chunkSize
    ss, sc = run_trials(chunkSize; testTime=13)
    push!(ss_list2, ss)
    push!(sc_list2, sc)
end
# Out:
# chunkSize = [256, 256, 1]
# saving speed: 29.49253566048951 MB/s
# 	From worker 5:	From worker 5: processing block in global range: 0-256_0-256_0-1
# 	From worker 9:	From worker 9: processing block in global range: 256-512_0-256_0-1
# 	From worker 4:	From worker 4: processing block in global range: 0-256_256-512_0-1
# 	From worker 5:	From worker 5: processing block in global range: 256-512_256-512_2-3
# 	From worker 12:	From worker 12: processing block in global range: 256-512_256-512_0-1
# 	From worker 9:	From worker 9: processing block in global range: 0-256_0-256_3-4
# 	From worker 10:	From worker 10: processing block in global range: 0-256_0-256_2-3
# 	From worker 3:	From worker 3: processing block in global range: 256-512_0-256_1-2
# 	From worker 4:	From worker 4: processing block in global range: 0-256_256-512_3-4
# 	From worker 4:	From worker 4: processing block in global range: 256-512_256-512_5-6
# 	From worker 5:	From worker 5: processing block in global range: 0-256_0-256_8-9
# 	From worker 11:	From worker 11: processing block in global range: 256-512_0-256_2-3
# 	From worker 12:	From worker 12: processing block in global range: 0-256_0-256_4-5
# 	From worker 2:	From worker 2: processing block in global range: 0-256_0-256_1-2
# 	From worker 9:	From worker 9: processing block in global range: 256-512_256-512_14-15
# 	From worker 9:	From worker 9: processing block in global range: 0-256_256-512_5-6
# 	From worker 8:	From worker 8: processing block in global range: 256-512_256-512_1-2
# 	From worker 10:	From worker 10: processing block in global range: 256-512_0-256_4-5
# 	From worker 10:	From worker 10: processing block in global range: 256-512_0-256_6-7
# 	From worker 3:	From worker 3: processing block in global range: 256-512_256-512_3-4
# 	From worker 3:	From worker 3: processing block in global range: 0-256_0-256_6-7
# 	From worker 3:	From worker 3: processing block in global range: 0-256_256-512_8-9
# 	From worker 3:	From worker 3: processing block in global range: 0-256_0-256_11-12
# 	From worker 6:	From worker 6: processing block in global range: 0-256_256-512_2-3
# 	From worker 4:	From worker 4: processing block in global range: 256-512_0-256_8-9
# 	From worker 4:	From worker 4: processing block in global range: 256-512_256-512_24-25
# 	From worker 4:	From worker 4: processing block in global range: 0-256_0-256_25-26
# 	From worker 4:	From worker 4: processing block in global range: 0-256_256-512_10-11
# 	From worker 7:	From worker 7: processing block in global range: 0-256_256-512_1-2
# 	From worker 5:	From worker 5: processing block in global range: 0-256_0-256_22-23
# 	From worker 5:	From worker 5: processing block in global range: 256-512_0-256_22-23
# 	From worker 5:	From worker 5: processing block in global range: 0-256_0-256_15-16
# 	From worker 11:	From worker 11: processing block in global range: 0-256_256-512_4-5
# 	From worker 12:	From worker 12: processing block in global range: 0-256_256-512_7-8
# 	From worker 12:	From worker 12: processing block in global range: 256-512_256-512_8-9
# 	From worker 12:	From worker 12: processing block in global range: 256-512_256-512_10-11
# 	From worker 12:	From worker 12: processing block in global range: 256-512_256-512_12-13
# 	From worker 12:	From worker 12: processing block in global range: 0-256_256-512_16-17
# 	From worker 2:	From worker 2: processing block in global range: 256-512_0-256_3-4
# 	From worker 2:	From worker 2: processing block in global range: 0-256_256-512_6-7
# 	From worker 2:	From worker 2: processing block in global range: 0-256_0-256_9-10
# 	From worker 2:	From worker 2: processing block in global range: 0-256_0-256_12-13
# 	From worker 2:	From worker 2: processing block in global range: 256-512_256-512_13-14
# 	From worker 2:	From worker 2: processing block in global range: 256-512_0-256_16-17
# 	From worker 2:	From worker 2: processing block in global range: 256-512_0-256_17-18
# 	From worker 2:	From worker 2: processing block in global range: 256-512_0-256_19-20
# 	From worker 9:	From worker 9: processing block in global range: 256-512_256-512_18-19
# 	From worker 9:	From worker 9: processing block in global range: 256-512_256-512_28-29
# 	From worker 9:	From worker 9: processing block in global range: 0-256_0-256_29-30
# 	From worker 9:	From worker 9: processing block in global range: 256-512_0-256_25-26
# 	From worker 9:	From worker 9: processing block in global range: 256-512_256-512_30-31
# 	From worker 8:	From worker 8: processing block in global range: 0-256_0-256_5-6
# 	From worker 8:	From worker 8: processing block in global range: 0-256_0-256_7-8
# 	From worker 8:	From worker 8: processing block in global range: 256-512_0-256_9-10
# 	From worker 8:	From worker 8: processing block in global range: 256-512_0-256_11-12
# 	From worker 8:	From worker 8: processing block in global range: 0-256_0-256_13-14
# 	From worker 8:	From worker 8: processing block in global range: 0-256_256-512_15-16
# 	From worker 8:	From worker 8: processing block in global range: 256-512_256-512_17-18
# 	From worker 8:	From worker 8: processing block in global range: 0-256_0-256_19-20
# 	From worker 10:	From worker 10: processing block in global range: 0-256_256-512_9-10
# 	From worker 10:	From worker 10: processing block in global range: 0-256_256-512_11-12
# 	From worker 10:	From worker 10: processing block in global range: 0-256_0-256_14-15
# 	From worker 10:	From worker 10: processing block in global range: 256-512_256-512_15-16
# 	From worker 10:	From worker 10: processing block in global range: 0-256_256-512_18-19
# 	From worker 10:	From worker 10: processing block in global range: 0-256_256-512_19-20
# 	From worker 10:	From worker 10: processing block in global range: 0-256_0-256_21-22
# 	From worker 3:	From worker 3: processing block in global range: 256-512_0-256_29-30
# 	From worker 3:	From worker 3: processing block in global range: 0-256_256-512_29-30
# 	From worker 3:	From worker 3: processing block in global range: 256-512_0-256_13-14
# 	From worker 3:	From worker 3: processing block in global range: 0-256_0-256_31-32
# 	From worker 3:	From worker 3: processing block in global range: 0-256_0-256_34-35
# 	From worker 3:	From worker 3: processing block in global range: 256-512_0-256_31-32
# 	From worker 3:	From worker 3: processing block in global range: 0-256_0-256_38-39
# 	From worker 3:	From worker 3: processing block in global range: 256-512_0-256_38-39
# 	From worker 6:	From worker 6: processing block in global range: 256-512_0-256_5-6
# 	From worker 6:	From worker 6: processing block in global range: 256-512_0-256_7-8
# 	From worker 6:	From worker 6: processing block in global range: 0-256_0-256_10-11
# 	From worker 6:	From worker 6: processing block in global range: 256-512_0-256_12-13
# 	From worker 6:	From worker 6: processing block in global range: 0-256_256-512_14-15
# 	From worker 6:	From worker 6: processing block in global range: 256-512_256-512_16-17
# 	From worker 6:	From worker 6: processing block in global range: 0-256_256-512_17-18
# 	From worker 6:	From worker 6: processing block in global range: 256-512_0-256_20-21
# 	From worker 6:	From worker 6: processing block in global range: 256-512_256-512_21-22
# 	From worker 6:	From worker 6: processing block in global range: 256-512_0-256_23-24
# 	From worker 6:	From worker 6: processing block in global range: 0-256_0-256_24-25
# 	From worker 6:	From worker 6: processing block in global range: 0-256_256-512_25-26
# 	From worker 6:	From worker 6: processing block in global range: 0-256_256-512_26-27
# 	From worker 4:	From worker 4: processing block in global range: 0-256_0-256_32-33
# 	From worker 4:	From worker 4: processing block in global range: 256-512_0-256_32-33
# 	From worker 4:	From worker 4: processing block in global range: 0-256_0-256_28-29
# 	From worker 4:	From worker 4: processing block in global range: 0-256_256-512_37-38
# 	From worker 4:	From worker 4: processing block in global range: 256-512_256-512_37-38
# 	From worker 4:	From worker 4: processing block in global range: 0-256_256-512_34-35
# 	From worker 7:	From worker 7: processing block in global range: 256-512_256-512_4-5
# 	From worker 7:	From worker 7: processing block in global range: 256-512_256-512_6-7
# 	From worker 7:	From worker 7: processing block in global range: 256-512_256-512_9-10
# 	From worker 7:	From worker 7: processing block in global range: 256-512_256-512_11-12
# 	From worker 7:	From worker 7: processing block in global range: 0-256_256-512_13-14
# 	From worker 7:	From worker 7: processing block in global range: 256-512_0-256_15-16
# 	From worker 7:	From worker 7: processing block in global range: 0-256_0-256_18-19
# 	From worker 7:	From worker 7: processing block in global range: 256-512_256-512_19-20
# 	From worker 7:	From worker 7: processing block in global range: 0-256_256-512_21-22
# 	From worker 7:	From worker 7: processing block in global range: 0-256_0-256_23-24
# 	From worker 7:	From worker 7: processing block in global range: 256-512_0-256_24-25
# 	From worker 7:	From worker 7: processing block in global range: 256-512_256-512_25-26
# 	From worker 7:	From worker 7: processing block in global range: 256-512_256-512_26-27
# 	From worker 7:	From worker 7: processing block in global range: 0-256_256-512_27-28
# 	From worker 7:	From worker 7: processing block in global range: 256-512_0-256_28-29
# 	From worker 5:	From worker 5: processing block in global range: 256-512_0-256_26-27
# 	From worker 5:	From worker 5: processing block in global range: 0-256_256-512_32-33
# 	From worker 5:	From worker 5: processing block in global range: 256-512_256-512_32-33
# 	From worker 5:	From worker 5: processing block in global range: 0-256_256-512_30-31
# 	From worker 5:	From worker 5: processing block in global range: 0-256_0-256_33-34
# 	From worker 5:	From worker 5: processing block in global range: 256-512_0-256_36-37
# 	From worker 5:	From worker 5: processing block in global range: 0-256_0-256_39-40
# 	From worker 5:	From worker 5: processing block in global range: 0-256_256-512_43-44
# 	From worker 5:	From worker 5: processing block in global range: 256-512_256-512_43-44
# 	From worker 5:	From worker 5: processing block in global range: 0-256_0-256_40-41
# 	From worker 11:	From worker 11: processing block in global range: 256-512_256-512_7-8
# 	From worker 11:	From worker 11: processing block in global range: 256-512_0-256_10-11
# 	From worker 11:	From worker 11: processing block in global range: 0-256_256-512_12-13
# 	From worker 11:	From worker 11: processing block in global range: 256-512_0-256_14-15
# 	From worker 11:	From worker 11: processing block in global range: 0-256_0-256_16-17
# 	From worker 11:	From worker 11: processing block in global range: 256-512_0-256_18-19
# 	From worker 11:	From worker 11: processing block in global range: 0-256_0-256_20-21
# 	From worker 11:	From worker 11: processing block in global range: 256-512_0-256_21-22
# 	From worker 11:	From worker 11: processing block in global range: 0-256_256-512_23-24
# 	From worker 11:	From worker 11: processing block in global range: 0-256_256-512_24-25
# 	From worker 11:	From worker 11: processing block in global range: 0-256_0-256_26-27
# 	From worker 11:	From worker 11: processing block in global range: 0-256_0-256_27-28
# 	From worker 11:	From worker 11: processing block in global range: 256-512_256-512_27-28
# 	From worker 11:	From worker 11: processing block in global range: 0-256_256-512_28-29
# 	From worker 11:	From worker 11: processing block in global range: 256-512_256-512_29-30
# 	From worker 11:	From worker 11: processing block in global range: 0-256_256-512_46-47
# 	From worker 11:	From worker 11: processing block in global range: 256-512_256-512_46-47
# 	From worker 12:	From worker 12: processing block in global range: 0-256_256-512_31-32
# 	From worker 12:	From worker 12: processing block in global range: 256-512_256-512_31-32
# 	From worker 12:	From worker 12: processing block in global range: 0-256_0-256_17-18
# 	From worker 12:	From worker 12: processing block in global range: 256-512_0-256_34-35
# 	From worker 12:	From worker 12: processing block in global range: 256-512_256-512_38-39
# 	From worker 12:	From worker 12: processing block in global range: 0-256_0-256_35-36
# 	From worker 12:	From worker 12: processing block in global range: 0-256_256-512_39-40
# 	From worker 12:	From worker 12: processing block in global range: 0-256_256-512_40-41
# 	From worker 12:	From worker 12: processing block in global range: 0-256_256-512_41-42
# 	From worker 12:	From worker 12: processing block in global range: 0-256_256-512_42-43
# 	From worker 12:	From worker 12: processing block in global range: 256-512_0-256_43-44
# 	From worker 2:	From worker 2: processing block in global range: 0-256_256-512_33-34
# 	From worker 2:	From worker 2: processing block in global range: 256-512_256-512_33-34
# 	From worker 2:	From worker 2: processing block in global range: 256-512_256-512_20-21
# 	From worker 2:	From worker 2: processing block in global range: 256-512_256-512_42-43
# 	From worker 2:	From worker 2: processing block in global range: 0-256_0-256_43-44
# 	From worker 2:	From worker 2: processing block in global range: 0-256_256-512_38-39
# 	From worker 2:	From worker 2: processing block in global range: 256-512_256-512_45-46
# 	From worker 2:	From worker 2: processing block in global range: 256-512_0-256_47-48
# 	From worker 2:	From worker 2: processing block in global range: 256-512_0-256_48-49
# 	From worker 2:	From worker 2: processing block in global range: 256-512_0-256_49-50
# 	From worker 2:	From worker 2: processing block in global range: 256-512_0-256_63-64
# 	From worker 2:	From worker 2: processing block in global range: 0-256_256-512_63-64
# 	From worker 2:	From worker 2: processing block in global range: 0-256_0-256_50-51
# 	From worker 9:	From worker 9: processing block in global range: 256-512_0-256_33-34
# 	From worker 9:	From worker 9: processing block in global range: 256-512_256-512_34-35
# 	From worker 9:	From worker 9: processing block in global range: 256-512_0-256_35-36
# 	From worker 9:	From worker 9: processing block in global range: 256-512_256-512_41-42
# 	From worker 9:	From worker 9: processing block in global range: 0-256_0-256_42-43
# 	From worker 9:	From worker 9: processing block in global range: 0-256_0-256_36-37
# 	From worker 9:	From worker 9: processing block in global range: 0-256_0-256_51-52
# 	From worker 9:	From worker 9: processing block in global range: 256-512_0-256_51-52
# 	From worker 9:	From worker 9: processing block in global range: 0-256_0-256_45-46
# 	From worker 9:	From worker 9: processing block in global range: 256-512_256-512_53-54
# 	From worker 9:	From worker 9: processing block in global range: 0-256_0-256_66-67
# 	From worker 9:	From worker 9: processing block in global range: 256-512_0-256_66-67
# 	From worker 9:	From worker 9: processing block in global range: 256-512_0-256_69-70
# 	From worker 9:	From worker 9: processing block in global range: 256-512_0-256_60-61
# 	From worker 8:	From worker 8: processing block in global range: 0-256_256-512_20-21
# 	From worker 8:	From worker 8: processing block in global range: 0-256_256-512_22-23
# 	From worker 8:	From worker 8: processing block in global range: 0-256_0-256_37-38
# 	From worker 8:	From worker 8: processing block in global range: 256-512_0-256_37-38
# 	From worker 8:	From worker 8: processing block in global range: 256-512_256-512_23-24
# 	From worker 8:	From worker 8: processing block in global range: 0-256_256-512_44-45
# 	From worker 8:	From worker 8: processing block in global range: 256-512_256-512_44-45
# 	From worker 8:	From worker 8: processing block in global range: 0-256_0-256_48-49
# 	From worker 8:	From worker 8: processing block in global range: 0-256_0-256_58-59
# 	From worker 8:	From worker 8: processing block in global range: 256-512_0-256_58-59
# 	From worker 8:	From worker 8: processing block in global range: 0-256_0-256_55-56
# 	From worker 8:	From worker 8: processing block in global range: 0-256_256-512_69-70
# 	From worker 8:	From worker 8: processing block in global range: 256-512_256-512_69-70
# 	From worker 8:	From worker 8: processing block in global range: 0-256_0-256_62-63
# 	From worker 8:	From worker 8: processing block in global range: 0-256_256-512_76-77
# 	From worker 8:	From worker 8: processing block in global range: 256-512_256-512_76-77
# 	From worker 8:	From worker 8: processing block in global range: 0-256_0-256_80-81
# 	From worker 8:	From worker 8: processing block in global range: 256-512_0-256_80-81
# 	From worker 10:	From worker 10: processing block in global range: 256-512_256-512_22-23
# 	From worker 10:	From worker 10: processing block in global range: 0-256_256-512_35-36
# 	From worker 10:	From worker 10: processing block in global range: 256-512_256-512_35-36
# 	From worker 10:	From worker 10: processing block in global range: 0-256_256-512_36-37
# 	From worker 10:	From worker 10: processing block in global range: 256-512_0-256_46-47
# 	From worker 10:	From worker 10: processing block in global range: 256-512_256-512_36-37
# 	From worker 10:	From worker 10: processing block in global range: 0-256_0-256_49-50
# 	From worker 10:	From worker 10: processing block in global range: 0-256_0-256_53-54
# 	From worker 10:	From worker 10: processing block in global range: 256-512_256-512_56-57
# 	From worker 10:	From worker 10: processing block in global range: 0-256_256-512_60-61
# 	From worker 10:	From worker 10: processing block in global range: 0-256_256-512_62-63
# 	From worker 10:	From worker 10: processing block in global range: 256-512_0-256_64-65
# 	From worker 10:	From worker 10: processing block in global range: 256-512_256-512_73-74
# 	From worker 10:	From worker 10: processing block in global range: 0-256_0-256_74-75
# 	From worker 10:	From worker 10: processing block in global range: 256-512_0-256_65-66
# 	From worker 10:	From worker 10: processing block in global range: 0-256_256-512_82-83
# 	From worker 10:	From worker 10: processing block in global range: 256-512_256-512_82-83
# 	From worker 10:	From worker 10: processing block in global range: 0-256_0-256_76-77
# 	From worker 10:	From worker 10: processing block in global range: 256-512_0-256_85-86
# 	From worker 3:	From worker 3: processing block in global range: 0-256_0-256_41-42
# 	From worker 3:	From worker 3: processing block in global range: 0-256_0-256_44-45
# 	From worker 3:	From worker 3: processing block in global range: 0-256_0-256_46-47
# 	From worker 3:	From worker 3: processing block in global range: 0-256_256-512_47-48
# 	From worker 3:	From worker 3: processing block in global range: 0-256_256-512_48-49
# 	From worker 3:	From worker 3: processing block in global range: 0-256_256-512_49-50
# 	From worker 3:	From worker 3: processing block in global range: 256-512_0-256_50-51
# 	From worker 3:	From worker 3: processing block in global range: 0-256_256-512_66-67
# 	From worker 3:	From worker 3: processing block in global range: 256-512_256-512_51-52
# 	From worker 3:	From worker 3: processing block in global range: 0-256_0-256_73-74
# 	From worker 3:	From worker 3: processing block in global range: 256-512_0-256_73-74
# 	From worker 3:	From worker 3: processing block in global range: 256-512_0-256_68-69
# 	From worker 3:	From worker 3: processing block in global range: 0-256_256-512_75-76
# 	From worker 3:	From worker 3: processing block in global range: 256-512_256-512_80-81
# 	From worker 3:	From worker 3: processing block in global range: 256-512_256-512_84-85
# 	From worker 3:	From worker 3: processing block in global range: 0-256_0-256_85-86
# 	From worker 3:	From worker 3: processing block in global range: 256-512_0-256_81-82
# 	From worker 3:	From worker 3: processing block in global range: 0-256_256-512_86-87
# 	From worker 3:	From worker 3: processing block in global range: 0-256_0-256_93-94
# 	From worker 3:	From worker 3: processing block in global range: 256-512_0-256_93-94
# 	From worker 3:	From worker 3: processing block in global range: 256-512_256-512_90-91
# 	From worker 6:	From worker 6: processing block in global range: 256-512_0-256_27-28
# 	From worker 6:	From worker 6: processing block in global range: 256-512_0-256_39-40
# 	From worker 6:	From worker 6: processing block in global range: 256-512_256-512_39-40
# 	From worker 6:	From worker 6: processing block in global range: 256-512_256-512_40-41
# 	From worker 6:	From worker 6: processing block in global range: 256-512_0-256_41-42
# 	From worker 6:	From worker 6: processing block in global range: 256-512_0-256_42-43
# 	From worker 6:	From worker 6: processing block in global range: 256-512_256-512_60-61
# 	From worker 6:	From worker 6: processing block in global range: 256-512_0-256_62-63
# 	From worker 6:	From worker 6: processing block in global range: 256-512_256-512_63-64
# 	From worker 6:	From worker 6: processing block in global range: 256-512_0-256_74-75
# 	From worker 6:	From worker 6: processing block in global range: 256-512_256-512_81-82
# 	From worker 6:	From worker 6: processing block in global range: 0-256_0-256_82-83
# 	From worker 6:	From worker 6: processing block in global range: 256-512_0-256_78-79
# 	From worker 6:	From worker 6: processing block in global range: 256-512_256-512_87-88
# 	From worker 6:	From worker 6: processing block in global range: 0-256_0-256_88-89
# 	From worker 6:	From worker 6: processing block in global range: 256-512_256-512_89-90
# 	From worker 6:	From worker 6: processing block in global range: 0-256_0-256_90-91
# 	From worker 6:	From worker 6: processing block in global range: 256-512_0-256_84-85
# 	From worker 6:	From worker 6: processing block in global range: 0-256_0-256_97-98
# 	From worker 6:	From worker 6: processing block in global range: 256-512_0-256_97-98
# 	From worker 6:	From worker 6: processing block in global range: 256-512_0-256_101-102
# 	From worker 6:	From worker 6: processing block in global range: 256-512_0-256_108-109
# 	From worker 6:	From worker 6: processing block in global range: 0-256_256-512_108-109
# 	From worker 6:	From worker 6: processing block in global range: 0-256_0-256_107-108
# 	From worker 4:	From worker 4: processing block in global range: 256-512_0-256_40-41
# 	From worker 4:	From worker 4: processing block in global range: 256-512_0-256_44-45
# 	From worker 4:	From worker 4: processing block in global range: 256-512_0-256_45-46
# 	From worker 4:	From worker 4: processing block in global range: 0-256_256-512_45-46
# 	From worker 4:	From worker 4: processing block in global range: 256-512_0-256_52-53
# 	From worker 4:	From worker 4: processing block in global range: 0-256_0-256_57-58
# 	From worker 4:	From worker 4: processing block in global range: 256-512_256-512_64-65
# 	From worker 4:	From worker 4: processing block in global range: 0-256_0-256_65-66
# 	From worker 4:	From worker 4: processing block in global range: 256-512_256-512_58-59
# 	From worker 4:	From worker 4: processing block in global range: 0-256_256-512_68-69
# 	From worker 4:	From worker 4: processing block in global range: 256-512_0-256_70-71
# 	From worker 4:	From worker 4: processing block in global range: 0-256_0-256_71-72
# 	From worker 4:	From worker 4: processing block in global range: 256-512_256-512_77-78
# 	From worker 4:	From worker 4: processing block in global range: 0-256_256-512_78-79
# 	From worker 4:	From worker 4: processing block in global range: 0-256_0-256_79-80
# 	From worker 4:	From worker 4: processing block in global range: 256-512_256-512_88-89
# 	From worker 4:	From worker 4: processing block in global range: 0-256_0-256_89-90
# 	From worker 4:	From worker 4: processing block in global range: 256-512_0-256_90-91
# 	From worker 4:	From worker 4: processing block in global range: 0-256_256-512_90-91
# 	From worker 4:	From worker 4: processing block in global range: 0-256_0-256_86-87
# 	From worker 4:	From worker 4: processing block in global range: 256-512_256-512_92-93
# 	From worker 4:	From worker 4: processing block in global range: 0-256_0-256_95-96
# 	From worker 4:	From worker 4: processing block in global range: 256-512_256-512_95-96
# 	From worker 4:	From worker 4: processing block in global range: 256-512_256-512_96-97
# 	From worker 4:	From worker 4: processing block in global range: 0-256_256-512_98-99
# 	From worker 4:	From worker 4: processing block in global range: 256-512_256-512_99-100
# 	From worker 7:	From worker 7: processing block in global range: 0-256_0-256_30-31
# 	From worker 7:	From worker 7: processing block in global range: 256-512_256-512_47-48
# 	From worker 7:	From worker 7: processing block in global range: 256-512_256-512_48-49
# 	From worker 7:	From worker 7: processing block in global range: 256-512_256-512_49-50
# 	From worker 7:	From worker 7: processing block in global range: 0-256_256-512_50-51
# 	From worker 7:	From worker 7: processing block in global range: 0-256_0-256_52-53
# 	From worker 7:	From worker 7: processing block in global range: 256-512_256-512_52-53
# 	From worker 7:	From worker 7: processing block in global range: 256-512_0-256_53-54
# 	From worker 7:	From worker 7: processing block in global range: 0-256_0-256_54-55
# 	From worker 7:	From worker 7: processing block in global range: 256-512_0-256_55-56
# 	From worker 7:	From worker 7: processing block in global range: 0-256_0-256_56-57
# 	From worker 7:	From worker 7: processing block in global range: 256-512_0-256_57-58
# 	From worker 7:	From worker 7: processing block in global range: 0-256_256-512_58-59
# 	From worker 7:	From worker 7: processing block in global range: 0-256_256-512_59-60
# 	From worker 7:	From worker 7: processing block in global range: 256-512_256-512_86-87
# 	From worker 7:	From worker 7: processing block in global range: 0-256_0-256_94-95
# 	From worker 7:	From worker 7: processing block in global range: 256-512_0-256_94-95
# 	From worker 7:	From worker 7: processing block in global range: 0-256_256-512_87-88
# 	From worker 7:	From worker 7: processing block in global range: 0-256_256-512_97-98
# 	From worker 7:	From worker 7: processing block in global range: 0-256_256-512_99-100
# 	From worker 7:	From worker 7: processing block in global range: 0-256_256-512_100-101
# 	From worker 7:	From worker 7: processing block in global range: 0-256_256-512_101-102
# 	From worker 7:	From worker 7: processing block in global range: 0-256_256-512_102-103
# 	From worker 7:	From worker 7: processing block in global range: 256-512_0-256_103-104
# 	From worker 7:	From worker 7: processing block in global range: 0-256_256-512_113-114
# 	From worker 7:	From worker 7: processing block in global range: 256-512_0-256_114-115
# 	From worker 7:	From worker 7: processing block in global range: 0-256_0-256_116-117
# 	From worker 7:	From worker 7: processing block in global range: 0-256_0-256_117-118
# 	From worker 7:	From worker 7: processing block in global range: 0-256_0-256_118-119
# 	From worker 5:	From worker 5: processing block in global range: 0-256_256-512_54-55
# 	From worker 5:	From worker 5: processing block in global range: 256-512_256-512_54-55
# 	From worker 5:	From worker 5: processing block in global range: 0-256_0-256_47-48
# 	From worker 5:	From worker 5: processing block in global range: 256-512_0-256_56-57
# 	From worker 5:	From worker 5: processing block in global range: 256-512_256-512_57-58
# 	From worker 5:	From worker 5: processing block in global range: 256-512_0-256_59-60
# 	From worker 5:	From worker 5: processing block in global range: 256-512_256-512_59-60
# 	From worker 5:	From worker 5: processing block in global range: 256-512_0-256_61-62
# 	From worker 5:	From worker 5: processing block in global range: 0-256_0-256_63-64
# 	From worker 5:	From worker 5: processing block in global range: 0-256_256-512_64-65
# 	From worker 5:	From worker 5: processing block in global range: 256-512_256-512_65-66
# 	From worker 5:	From worker 5: processing block in global range: 256-512_0-256_67-68
# 	From worker 5:	From worker 5: processing block in global range: 0-256_0-256_68-69
# 	From worker 5:	From worker 5: processing block in global range: 0-256_0-256_69-70
# 	From worker 5:	From worker 5: processing block in global range: 0-256_256-512_70-71
# 	From worker 5:	From worker 5: processing block in global range: 256-512_0-256_71-72
# 	From worker 5:	From worker 5: processing block in global range: 256-512_256-512_71-72
# 	From worker 5:	From worker 5: processing block in global range: 256-512_256-512_72-73
# 	From worker 5:	From worker 5: processing block in global range: 0-256_256-512_93-94
# 	From worker 5:	From worker 5: processing block in global range: 256-512_256-512_93-94
# 	From worker 5:	From worker 5: processing block in global range: 0-256_256-512_73-74
# 	From worker 5:	From worker 5: processing block in global range: 256-512_0-256_98-99
# 	From worker 5:	From worker 5: processing block in global range: 0-256_0-256_100-101
# 	From worker 5:	From worker 5: processing block in global range: 256-512_256-512_112-113
# 	From worker 5:	From worker 5: processing block in global range: 256-512_256-512_118-119
# 	From worker 5:	From worker 5: processing block in global range: 256-512_256-512_124-125
# 	From worker 5:	From worker 5: processing block in global range: 0-256_0-256_125-126
# 	From worker 5:	From worker 5: processing block in global range: 0-256_0-256_122-123
# 	From worker 5:	From worker 5: processing block in global range: 256-512_0-256_128-129
# 	From worker 5:	From worker 5: processing block in global range: 0-256_256-512_133-134
# 	From worker 5:	From worker 5: processing block in global range: 0-256_0-256_134-135
# 	From worker 5:	From worker 5: processing block in global range: 256-512_0-256_134-135
# 	From worker 11:	From worker 11: processing block in global range: 256-512_0-256_30-31
# 	From worker 11:	From worker 11: processing block in global range: 256-512_256-512_50-51
# 	From worker 11:	From worker 11: processing block in global range: 0-256_256-512_51-52
# 	From worker 11:	From worker 11: processing block in global range: 0-256_256-512_52-53
# 	From worker 11:	From worker 11: processing block in global range: 0-256_256-512_53-54
# 	From worker 11:	From worker 11: processing block in global range: 256-512_0-256_54-55
# 	From worker 11:	From worker 11: processing block in global range: 0-256_256-512_55-56
# 	From worker 11:	From worker 11: processing block in global range: 0-256_256-512_56-57
# 	From worker 11:	From worker 11: processing block in global range: 0-256_256-512_57-58
# 	From worker 11:	From worker 11: processing block in global range: 0-256_0-256_59-60
# 	From worker 11:	From worker 11: processing block in global range: 0-256_0-256_60-61
# 	From worker 11:	From worker 11: processing block in global range: 0-256_0-256_61-62
# 	From worker 11:	From worker 11: processing block in global range: 256-512_256-512_62-63
# 	From worker 11:	From worker 11: processing block in global range: 0-256_0-256_64-65
# 	From worker 11:	From worker 11: processing block in global range: 0-256_256-512_65-66
# 	From worker 11:	From worker 11: processing block in global range: 0-256_0-256_67-68
# 	From worker 11:	From worker 11: processing block in global range: 256-512_256-512_67-68
# 	From worker 11:	From worker 11: processing block in global range: 256-512_256-512_68-69
# 	From worker 11:	From worker 11: processing block in global range: 0-256_0-256_70-71
# 	From worker 11:	From worker 11: processing block in global range: 256-512_256-512_70-71
# 	From worker 11:	From worker 11: processing block in global range: 0-256_256-512_71-72
# 	From worker 11:	From worker 11: processing block in global range: 256-512_0-256_110-111
# 	From worker 11:	From worker 11: processing block in global range: 0-256_0-256_111-112
# 	From worker 11:	From worker 11: processing block in global range: 256-512_256-512_111-112
# 	From worker 11:	From worker 11: processing block in global range: 0-256_256-512_112-113
# 	From worker 11:	From worker 11: processing block in global range: 256-512_0-256_113-114
# 	From worker 11:	From worker 11: processing block in global range: 0-256_256-512_114-115
# 	From worker 11:	From worker 11: processing block in global range: 256-512_256-512_115-116
# 	From worker 11:	From worker 11: processing block in global range: 0-256_0-256_135-136
# 	From worker 11:	From worker 11: processing block in global range: 256-512_256-512_116-117
# 	From worker 11:	From worker 11: processing block in global range: 0-256_0-256_139-140
# 	From worker 11:	From worker 11: processing block in global range: 0-256_256-512_145-146
# 	From worker 11:	From worker 11: processing block in global range: 256-512_256-512_145-146
# 	From worker 11:	From worker 11: processing block in global range: 0-256_0-256_140-141
# 	From worker 11:	From worker 11: processing block in global range: 256-512_256-512_156-157
# 	From worker 11:	From worker 11: processing block in global range: 0-256_0-256_157-158
# 	From worker 11:	From worker 11: processing block in global range: 256-512_256-512_158-159
# 	From worker 12:	From worker 12: processing block in global range: 0-256_256-512_61-62
# 	From worker 12:	From worker 12: processing block in global range: 256-512_256-512_61-62
# 	From worker 12:	From worker 12: processing block in global range: 256-512_256-512_55-56
# 	From worker 12:	From worker 12: processing block in global range: 0-256_0-256_72-73
# 	From worker 12:	From worker 12: processing block in global range: 256-512_0-256_72-73
# 	From worker 12:	From worker 12: processing block in global range: 256-512_256-512_74-75
# 	From worker 12:	From worker 12: processing block in global range: 0-256_0-256_75-76
# 	From worker 12:	From worker 12: processing block in global range: 256-512_256-512_66-67
# 	From worker 12:	From worker 12: processing block in global range: 256-512_256-512_75-76
# 	From worker 12:	From worker 12: processing block in global range: 256-512_0-256_76-77
# 	From worker 12:	From worker 12: processing block in global range: 256-512_0-256_77-78
# 	From worker 12:	From worker 12: processing block in global range: 0-256_0-256_78-79
# 	From worker 12:	From worker 12: processing block in global range: 256-512_256-512_78-79
# 	From worker 12:	From worker 12: processing block in global range: 256-512_0-256_79-80
# 	From worker 12:	From worker 12: processing block in global range: 0-256_0-256_81-82
# 	From worker 12:	From worker 12: processing block in global range: 0-256_256-512_81-82
# 	From worker 12:	From worker 12: processing block in global range: 256-512_0-256_82-83
# 	From worker 12:	From worker 12: processing block in global range: 0-256_256-512_92-93
# 	From worker 12:	From worker 12: processing block in global range: 256-512_256-512_94-95
# 	From worker 12:	From worker 12: processing block in global range: 0-256_256-512_95-96
# 	From worker 12:	From worker 12: processing block in global range: 0-256_256-512_96-97
# 	From worker 12:	From worker 12: processing block in global range: 256-512_0-256_111-112
# 	From worker 12:	From worker 12: processing block in global range: 0-256_256-512_118-119
# 	From worker 12:	From worker 12: processing block in global range: 0-256_0-256_120-121
# 	From worker 12:	From worker 12: processing block in global range: 0-256_0-256_126-127
# 	From worker 12:	From worker 12: processing block in global range: 256-512_0-256_126-127
# 	From worker 12:	From worker 12: processing block in global range: 0-256_0-256_121-122
# 	From worker 12:	From worker 12: processing block in global range: 256-512_0-256_129-130
# 	From worker 12:	From worker 12: processing block in global range: 256-512_256-512_134-135
# 	From worker 12:	From worker 12: processing block in global range: 256-512_256-512_130-131
# 	From worker 12:	From worker 12: processing block in global range: 0-256_0-256_138-139
# 	From worker 12:	From worker 12: processing block in global range: 256-512_0-256_139-140
# 	From worker 12:	From worker 12: processing block in global range: 256-512_0-256_140-141
# 	From worker 12:	From worker 12: processing block in global range: 256-512_256-512_150-151
# 	From worker 12:	From worker 12: processing block in global range: 0-256_0-256_151-152
# 	From worker 12:	From worker 12: processing block in global range: 256-512_256-512_154-155
# 	From worker 12:	From worker 12: processing block in global range: 0-256_0-256_155-156
# 	From worker 12:	From worker 12: processing block in global range: 0-256_256-512_157-158
# 	From worker 12:	From worker 12: processing block in global range: 0-256_256-512_141-142
# 	From worker 12:	From worker 12: processing block in global range: 0-256_0-256_162-163
# 	From worker 12:	From worker 12: processing block in global range: 256-512_0-256_166-167
# 	From worker 2:	From worker 2: processing block in global range: 0-256_256-512_67-68
# 	From worker 2:	From worker 2: processing block in global range: 0-256_256-512_74-75
# 	From worker 2:	From worker 2: processing block in global range: 0-256_0-256_77-78
# 	From worker 2:	From worker 2: processing block in global range: 0-256_256-512_80-81
# 	From worker 2:	From worker 2: processing block in global range: 0-256_256-512_83-84
# 	From worker 2:	From worker 2: processing block in global range: 0-256_0-256_84-85
# 	From worker 2:	From worker 2: processing block in global range: 0-256_256-512_84-85
# 	From worker 2:	From worker 2: processing block in global range: 0-256_256-512_85-86
# 	From worker 2:	From worker 2: processing block in global range: 256-512_256-512_85-86
# 	From worker 2:	From worker 2: processing block in global range: 0-256_256-512_91-92
# 	From worker 2:	From worker 2: processing block in global range: 256-512_256-512_98-99
# 	From worker 2:	From worker 2: processing block in global range: 0-256_0-256_99-100
# 	From worker 2:	From worker 2: processing block in global range: 0-256_0-256_92-93
# 	From worker 2:	From worker 2: processing block in global range: 256-512_0-256_102-103
# 	From worker 2:	From worker 2: processing block in global range: 256-512_0-256_107-108
# 	From worker 2:	From worker 2: processing block in global range: 256-512_0-256_109-110
# 	From worker 2:	From worker 2: processing block in global range: 256-512_256-512_109-110
# 	From worker 2:	From worker 2: processing block in global range: 0-256_256-512_110-111
# 	From worker 2:	From worker 2: processing block in global range: 0-256_256-512_111-112
# 	From worker 2:	From worker 2: processing block in global range: 256-512_0-256_112-113
# 	From worker 2:	From worker 2: processing block in global range: 0-256_0-256_113-114
# 	From worker 2:	From worker 2: processing block in global range: 0-256_0-256_114-115
# 	From worker 2:	From worker 2: processing block in global range: 0-256_256-512_115-116
# 	From worker 2:	From worker 2: processing block in global range: 0-256_256-512_128-129
# 	From worker 2:	From worker 2: processing block in global range: 256-512_256-512_129-130
# 	From worker 2:	From worker 2: processing block in global range: 0-256_256-512_130-131
# 	From worker 2:	From worker 2: processing block in global range: 0-256_256-512_137-138
# 	From worker 2:	From worker 2: processing block in global range: 0-256_0-256_141-142
# 	From worker 2:	From worker 2: processing block in global range: 0-256_0-256_132-133
# 	From worker 2:	From worker 2: processing block in global range: 256-512_256-512_142-143
# 	From worker 2:	From worker 2: processing block in global range: 0-256_256-512_143-144
# 	From worker 2:	From worker 2: processing block in global range: 256-512_0-256_156-157
# 	From worker 2:	From worker 2: processing block in global range: 0-256_256-512_156-157
# 	From worker 2:	From worker 2: processing block in global range: 0-256_0-256_159-160
# 	From worker 2:	From worker 2: processing block in global range: 256-512_256-512_144-145
# 	From worker 2:	From worker 2: processing block in global range: 256-512_0-256_159-160
# 	From worker 2:	From worker 2: processing block in global range: 256-512_256-512_163-164
# 	From worker 2:	From worker 2: processing block in global range: 0-256_256-512_164-165
# 	From worker 2:	From worker 2: processing block in global range: 256-512_256-512_169-170
# 	From worker 9:	From worker 9: processing block in global range: 256-512_0-256_75-76
# 	From worker 9:	From worker 9: processing block in global range: 0-256_256-512_79-80
# 	From worker 9:	From worker 9: processing block in global range: 256-512_256-512_79-80
# 	From worker 9:	From worker 9: processing block in global range: 0-256_256-512_77-78
# 	From worker 9:	From worker 9: processing block in global range: 256-512_0-256_83-84
# 	From worker 9:	From worker 9: processing block in global range: 256-512_0-256_86-87
# 	From worker 9:	From worker 9: processing block in global range: 0-256_0-256_87-88
# 	From worker 9:	From worker 9: processing block in global range: 256-512_0-256_87-88
# 	From worker 9:	From worker 9: processing block in global range: 256-512_0-256_88-89
# 	From worker 9:	From worker 9: processing block in global range: 256-512_256-512_91-92
# 	From worker 9:	From worker 9: processing block in global range: 256-512_0-256_92-93
# 	From worker 9:	From worker 9: processing block in global range: 0-256_256-512_94-95
# 	From worker 9:	From worker 9: processing block in global range: 0-256_256-512_104-105
# 	From worker 9:	From worker 9: processing block in global range: 0-256_0-256_108-109
# 	From worker 9:	From worker 9: processing block in global range: 0-256_0-256_110-111
# 	From worker 9:	From worker 9: processing block in global range: 256-512_256-512_114-115
# 	From worker 9:	From worker 9: processing block in global range: 256-512_256-512_110-111
# 	From worker 9:	From worker 9: processing block in global range: 256-512_0-256_116-117
# 	From worker 9:	From worker 9: processing block in global range: 0-256_256-512_116-117
# 	From worker 9:	From worker 9: processing block in global range: 256-512_0-256_118-119
# 	From worker 9:	From worker 9: processing block in global range: 256-512_0-256_119-120
# 	From worker 9:	From worker 9: processing block in global range: 256-512_256-512_119-120
# 	From worker 9:	From worker 9: processing block in global range: 0-256_256-512_120-121
# 	From worker 9:	From worker 9: processing block in global range: 256-512_256-512_121-122
# 	From worker 9:	From worker 9: processing block in global range: 0-256_256-512_122-123
# 	From worker 9:	From worker 9: processing block in global range: 0-256_256-512_123-124
# 	From worker 9:	From worker 9: processing block in global range: 0-256_0-256_124-125
# 	From worker 9:	From worker 9: processing block in global range: 0-256_256-512_124-125
# 	From worker 9:	From worker 9: processing block in global range: 0-256_256-512_125-126
# 	From worker 9:	From worker 9: processing block in global range: 256-512_0-256_141-142
# 	From worker 9:	From worker 9: processing block in global range: 0-256_256-512_126-127
# 	From worker 9:	From worker 9: processing block in global range: 0-256_256-512_142-143
# 	From worker 9:	From worker 9: processing block in global range: 256-512_0-256_143-144
# 	From worker 9:	From worker 9: processing block in global range: 256-512_0-256_144-145
# 	From worker 9:	From worker 9: processing block in global range: 0-256_0-256_146-147
# 	From worker 9:	From worker 9: processing block in global range: 256-512_256-512_166-167
# 	From worker 9:	From worker 9: processing block in global range: 0-256_0-256_167-168
# 	From worker 9:	From worker 9: processing block in global range: 256-512_0-256_172-173
# 	From worker 9:	From worker 9: processing block in global range: 0-256_256-512_172-173
# 	From worker 9:	From worker 9: processing block in global range: 0-256_256-512_161-162
# 	From worker 9:	From worker 9: processing block in global range: 0-256_0-256_176-177
# 	From worker 9:	From worker 9: processing block in global range: 256-512_256-512_186-187
# 	From worker 9:	From worker 9: processing block in global range: 0-256_0-256_187-188
# 	From worker 9:	From worker 9: processing block in global range: 0-256_0-256_177-178
# 	From worker 9:	From worker 9: processing block in global range: 256-512_256-512_189-190
# 	From worker 9:	From worker 9: processing block in global range: 256-512_0-256_195-196
# 	From worker 8:	From worker 8: processing block in global range: 0-256_256-512_72-73
# 	From worker 8:	From worker 8: processing block in global range: 0-256_0-256_83-84
# 	From worker 8:	From worker 8: processing block in global range: 0-256_256-512_89-90
# 	From worker 8:	From worker 8: processing block in global range: 256-512_256-512_83-84
# 	From worker 8:	From worker 8: processing block in global range: 256-512_0-256_91-92
# 	From worker 8:	From worker 8: processing block in global range: 256-512_0-256_95-96
# 	From worker 8:	From worker 8: processing block in global range: 0-256_0-256_98-99
# 	From worker 8:	From worker 8: processing block in global range: 256-512_0-256_99-100
# 	From worker 8:	From worker 8: processing block in global range: 256-512_256-512_100-101
# 	From worker 8:	From worker 8: processing block in global range: 0-256_0-256_102-103
# 	From worker 8:	From worker 8: processing block in global range: 256-512_256-512_102-103
# 	From worker 8:	From worker 8: processing block in global range: 0-256_256-512_103-104
# 	From worker 8:	From worker 8: processing block in global range: 256-512_256-512_104-105
# 	From worker 8:	From worker 8: processing block in global range: 256-512_0-256_105-106
# 	From worker 8:	From worker 8: processing block in global range: 256-512_256-512_113-114
# 	From worker 8:	From worker 8: processing block in global range: 256-512_0-256_127-128
# 	From worker 8:	From worker 8: processing block in global range: 0-256_256-512_127-128
# 	From worker 8:	From worker 8: processing block in global range: 0-256_256-512_131-132
# 	From worker 8:	From worker 8: processing block in global range: 256-512_256-512_131-132
# 	From worker 8:	From worker 8: processing block in global range: 256-512_256-512_123-124
# 	From worker 8:	From worker 8: processing block in global range: 256-512_256-512_133-134
# 	From worker 8:	From worker 8: processing block in global range: 0-256_0-256_136-137
# 	From worker 8:	From worker 8: processing block in global range: 256-512_256-512_137-138
# 	From worker 8:	From worker 8: processing block in global range: 256-512_256-512_141-142
# 	From worker 8:	From worker 8: processing block in global range: 256-512_0-256_142-143
# 	From worker 8:	From worker 8: processing block in global range: 256-512_256-512_143-144
# 	From worker 8:	From worker 8: processing block in global range: 0-256_0-256_145-146
# 	From worker 8:	From worker 8: processing block in global range: 0-256_256-512_146-147
# 	From worker 8:	From worker 8: processing block in global range: 0-256_0-256_160-161
# 	From worker 8:	From worker 8: processing block in global range: 256-512_0-256_160-161
# 	From worker 8:	From worker 8: processing block in global range: 0-256_0-256_147-148
# 	From worker 8:	From worker 8: processing block in global range: 256-512_0-256_161-162
# 	From worker 8:	From worker 8: processing block in global range: 256-512_0-256_165-166
# 	From worker 8:	From worker 8: processing block in global range: 0-256_0-256_166-167
# 	From worker 8:	From worker 8: processing block in global range: 256-512_256-512_167-168
# 	From worker 8:	From worker 8: processing block in global range: 256-512_0-256_169-170
# 	From worker 8:	From worker 8: processing block in global range: 256-512_0-256_170-171
# 	From worker 8:	From worker 8: processing block in global range: 0-256_0-256_171-172
# 	From worker 8:	From worker 8: processing block in global range: 0-256_256-512_188-189
# 	From worker 8:	From worker 8: processing block in global range: 256-512_256-512_188-189
# 	From worker 8:	From worker 8: processing block in global range: 256-512_0-256_173-174
# 	From worker 8:	From worker 8: processing block in global range: 256-512_256-512_191-192
# 	From worker 8:	From worker 8: processing block in global range: 0-256_0-256_192-193
# 	From worker 8:	From worker 8: processing block in global range: 256-512_0-256_197-198
# 	From worker 8:	From worker 8: processing block in global range: 256-512_256-512_192-193
# 	From worker 8:	From worker 8: processing block in global range: 256-512_256-512_197-198
# 	From worker 10:	From worker 10: processing block in global range: 0-256_256-512_88-89
# 	From worker 10:	From worker 10: processing block in global range: 256-512_0-256_89-90
# 	From worker 10:	From worker 10: processing block in global range: 0-256_0-256_96-97
# 	From worker 10:	From worker 10: processing block in global range: 256-512_0-256_96-97
# 	From worker 10:	From worker 10: processing block in global range: 0-256_0-256_91-92
# 	From worker 10:	From worker 10: processing block in global range: 256-512_0-256_100-101
# ...
# 	From worker 12:	From worker 12: processing block in global range: 256-512_256-512_489-490
# 	From worker 2:	From worker 2: processing block in global range: 0-256_256-512_506-507
# 	From worker 2:	From worker 2: processing block in global range: 256-512_256-512_506-507
# 	From worker 12:	From worker 12: processing block in global range: 0-256_0-256_490-491
# 	From worker 2:	From worker 2: processing block in global range: 0-256_0-256_507-508
# 	From worker 12:	From worker 12: processing block in global range: 256-512_0-256_490-491
# 	From worker 2:	From worker 2: processing block in global range: 256-512_0-256_507-508
# 	From worker 12:	From worker 12: processing block in global range: 0-256_256-512_490-491
# 	From worker 2:	From worker 2: processing block in global range: 0-256_256-512_507-508
# 	From worker 2:	From worker 2: processing block in global range: 0-256_256-512_509-510
# 	From worker 12:	From worker 12: processing block in global range: 256-512_256-512_490-491
# 	From worker 2:	From worker 2: processing block in global range: 256-512_256-512_509-510
# 	From worker 12:	From worker 12: processing block in global range: 0-256_0-256_491-492
# 	From worker 2:	From worker 2: processing block in global range: 0-256_0-256_510-511
# 	From worker 12:	From worker 12: processing block in global range: 256-512_0-256_501-502
# 	From worker 2:	From worker 2: processing block in global range: 256-512_0-256_510-511
# 	From worker 12:	From worker 12: processing block in global range: 0-256_256-512_501-502
# 	From worker 2:	From worker 2: processing block in global range: 0-256_256-512_510-511
# 	From worker 2:	From worker 2: processing block in global range: 256-512_256-512_510-511
# 	From worker 12:	From worker 12: processing block in global range: 256-512_256-512_501-502
# 	From worker 2:	From worker 2: processing block in global range: 0-256_0-256_511-512
# 	From worker 12:	From worker 12: processing block in global range: 0-256_0-256_502-503
# 	From worker 12:	From worker 12: processing block in global range: 256-512_0-256_502-503
# 	From worker 12:	From worker 12: processing block in global range: 0-256_256-512_502-503
# 	From worker 12:	From worker 12: processing block in global range: 256-512_256-512_502-503
# 	From worker 12:	From worker 12: processing block in global range: 0-256_0-256_503-504
# 	From worker 12:	From worker 12: processing block in global range: 256-512_0-256_509-510
# 	From worker 6:	From worker 6: processing block in global range: 0-256_0-256_317-318
# 	From worker 7:	From worker 7: processing block in global range: 256-512_256-512_310-311
# 	From worker 11:	From worker 11: processing block in global range: 0-256_0-256_372-373
# 	From worker 10:	From worker 10: processing block in global range: 256-512_0-256_215-216
# 	From worker 8:	From worker 8: processing block in global range: 0-256_0-256_342-343
# 	From worker 4:	From worker 4: processing block in global range: 0-256_0-256_346-347
# 	From worker 3:	From worker 3: processing block in global range: 256-512_0-256_176-177
# 	From worker 6:	From worker 6: processing block in global range: 256-512_0-256_317-318
# 	From worker 7:	From worker 7: processing block in global range: 0-256_0-256_311-312
# 	From worker 10:	From worker 10: processing block in global range: 0-256_256-512_215-216
# 	From worker 11:	From worker 11: processing block in global range: 256-512_0-256_372-373
# 	From worker 8:	From worker 8: processing block in global range: 256-512_0-256_342-343
# 	From worker 4:	From worker 4: processing block in global range: 256-512_0-256_346-347
# 	From worker 3:	From worker 3: processing block in global range: 0-256_256-512_176-177
# 	From worker 11:	From worker 11: processing block in global range: 0-256_256-512_372-373
# 	From worker 6:	From worker 6: processing block in global range: 0-256_256-512_317-318
# 	From worker 10:	From worker 10: processing block in global range: 256-512_256-512_215-216
# 	From worker 7:	From worker 7: processing block in global range: 256-512_0-256_311-312
# 	From worker 4:	From worker 4: processing block in global range: 0-256_256-512_346-347
# 	From worker 7:	From worker 7: processing block in global range: 0-256_256-512_311-312
# 	From worker 11:	From worker 11: processing block in global range: 256-512_256-512_372-373
# 	From worker 3:	From worker 3: processing block in global range: 256-512_256-512_176-177
# 	From worker 8:	From worker 8: processing block in global range: 0-256_256-512_342-343
# 	From worker 6:	From worker 6: processing block in global range: 256-512_256-512_375-376
# 	From worker 10:	From worker 10: processing block in global range: 0-256_0-256_216-217
# 	From worker 4:	From worker 4: processing block in global range: 256-512_256-512_346-347
# 	From worker 7:	From worker 7: processing block in global range: 256-512_256-512_311-312
# 	From worker 11:	From worker 11: processing block in global range: 0-256_0-256_373-374
# 	From worker 11:	From worker 11: processing block in global range: 256-512_0-256_373-374
# 	From worker 3:	From worker 3: processing block in global range: 0-256_0-256_173-174
# 	From worker 3:	From worker 3: processing block in global range: 256-512_0-256_173-174
# 	From worker 3:	From worker 3: processing block in global range: 0-256_256-512_173-174
# 	From worker 3:	From worker 3: processing block in global range: 256-512_256-512_173-174
# 	From worker 3:	From worker 3: processing block in global range: 0-256_0-256_174-175
# 	From worker 8:	From worker 8: processing block in global range: 256-512_256-512_342-343
# 	From worker 6:	From worker 6: processing block in global range: 0-256_0-256_376-377
# 	From worker 6:	From worker 6: processing block in global range: 256-512_0-256_376-377
# 	From worker 6:	From worker 6: processing block in global range: 0-256_256-512_376-377
# 	From worker 6:	From worker 6: processing block in global range: 256-512_256-512_376-377
# 	From worker 6:	From worker 6: processing block in global range: 0-256_256-512_405-406
# 	From worker 6:	From worker 6: processing block in global range: 256-512_256-512_405-406
# 	From worker 6:	From worker 6: processing block in global range: 0-256_0-256_406-407
# 	From worker 6:	From worker 6: processing block in global range: 256-512_0-256_406-407
# 	From worker 6:	From worker 6: processing block in global range: 0-256_256-512_406-407
# 	From worker 6:	From worker 6: processing block in global range: 256-512_256-512_406-407
# 	From worker 6:	From worker 6: processing block in global range: 0-256_0-256_407-408
# 	From worker 6:	From worker 6: processing block in global range: 256-512_0-256_407-408
# 	From worker 6:	From worker 6: processing block in global range: 0-256_256-512_407-408
# 	From worker 6:	From worker 6: processing block in global range: 256-512_256-512_407-408
# 	From worker 10:	From worker 10: processing block in global range: 256-512_0-256_216-217
# 	From worker 10:	From worker 10: processing block in global range: 0-256_256-512_216-217
# 	From worker 10:	From worker 10: processing block in global range: 256-512_256-512_216-217
# 	From worker 10:	From worker 10: processing block in global range: 0-256_0-256_217-218
# 	From worker 10:	From worker 10: processing block in global range: 256-512_0-256_217-218
# 	From worker 10:	From worker 10: processing block in global range: 0-256_256-512_217-218
# 	From worker 4:	From worker 4: processing block in global range: 0-256_0-256_347-348
# 	From worker 4:	From worker 4: processing block in global range: 256-512_0-256_347-348
# 	From worker 4:	From worker 4: processing block in global range: 0-256_256-512_347-348
# 	From worker 4:	From worker 4: processing block in global range: 256-512_256-512_347-348
# 	From worker 4:	From worker 4: processing block in global range: 0-256_0-256_348-349
# 	From worker 4:	From worker 4: processing block in global range: 256-512_0-256_348-349
# 	From worker 4:	From worker 4: processing block in global range: 0-256_256-512_348-349
# 	From worker 4:	From worker 4: processing block in global range: 256-512_256-512_348-349
# 	From worker 4:	From worker 4: processing block in global range: 0-256_0-256_349-350
# 	From worker 4:	From worker 4: processing block in global range: 256-512_0-256_349-350
# 	From worker 4:	From worker 4: processing block in global range: 0-256_256-512_349-350
# 	From worker 4:	From worker 4: processing block in global range: 256-512_0-256_503-504
# 	From worker 4:	From worker 4: processing block in global range: 0-256_256-512_503-504
# 	From worker 4:	From worker 4: processing block in global range: 256-512_256-512_503-504
# 	From worker 7:	From worker 7: processing block in global range: 0-256_0-256_312-313
# 	From worker 7:	From worker 7: processing block in global range: 256-512_0-256_312-313
# 	From worker 7:	From worker 7: processing block in global range: 0-256_256-512_312-313
# 	From worker 7:	From worker 7: processing block in global range: 256-512_256-512_312-313
# 	From worker 7:	From worker 7: processing block in global range: 0-256_0-256_313-314
# 	From worker 7:	From worker 7: processing block in global range: 0-256_256-512_365-366
# 	From worker 7:	From worker 7: processing block in global range: 256-512_256-512_365-366
# 	From worker 7:	From worker 7: processing block in global range: 0-256_0-256_366-367
# 	From worker 7:	From worker 7: processing block in global range: 256-512_0-256_366-367
# 	From worker 7:	From worker 7: processing block in global range: 0-256_256-512_366-367
# 	From worker 7:	From worker 7: processing block in global range: 256-512_256-512_366-367
# 	From worker 7:	From worker 7: processing block in global range: 0-256_0-256_367-368
# 	From worker 7:	From worker 7: processing block in global range: 256-512_0-256_367-368
# 	From worker 7:	From worker 7: processing block in global range: 0-256_256-512_367-368
# cutout speed: 18.726210755754636 MB/s
# 	From worker 11:	From worker 11: processing block in global range: 0-256_256-512_373-374
# 	From worker 11:	From worker 11: processing block in global range: 256-512_256-512_373-374
# 	From worker 11:	From worker 11: processing block in global range: 0-256_0-256_374-375
# 	From worker 11:	From worker 11: processing block in global range: 256-512_0-256_374-375
# 	From worker 11:	From worker 11: processing block in global range: 0-256_256-512_374-375
# 	From worker 11:	From worker 11: processing block in global range: 256-512_256-512_374-375
# 	From worker 11:	From worker 11: processing block in global range: 0-256_0-256_375-376
# 	From worker 11:	From worker 11: processing block in global range: 256-512_0-256_375-376
# 	From worker 11:	From worker 11: processing block in global range: 0-256_256-512_375-376
# 	From worker 11:	From worker 11: processing block in global range: 256-512_0-256_400-401
# 	From worker 11:	From worker 11: processing block in global range: 0-256_256-512_400-401
# 	From worker 3:	From worker 3: processing block in global range: 0-256_0-256_170-171
# 	From worker 3:	From worker 3: processing block in global range: 256-512_0-256_170-171
# 	From worker 3:	From worker 3: processing block in global range: 0-256_256-512_170-171
# 	From worker 3:	From worker 3: processing block in global range: 256-512_256-512_170-171
# 	From worker 3:	From worker 3: processing block in global range: 0-256_0-256_171-172
# 	From worker 3:	From worker 3: processing block in global range: 256-512_0-256_167-168
# 	From worker 3:	From worker 3: processing block in global range: 0-256_256-512_167-168
# 	From worker 3:	From worker 3: processing block in global range: 256-512_256-512_167-168
# 	From worker 3:	From worker 3: processing block in global range: 0-256_0-256_168-169
# 	From worker 3:	From worker 3: processing block in global range: 256-512_0-256_168-169
# 	From worker 3:	From worker 3: processing block in global range: 0-256_256-512_168-169
# 	From worker 3:	From worker 3: processing block in global range: 256-512_256-512_168-169
# 	From worker 6:	From worker 6: processing block in global range: 0-256_0-256_408-409
# 	From worker 6:	From worker 6: processing block in global range: 256-512_256-512_432-433
# 	From worker 6:	From worker 6: processing block in global range: 0-256_0-256_433-434
# 	From worker 6:	From worker 6: processing block in global range: 256-512_0-256_433-434
# 	From worker 6:	From worker 6: processing block in global range: 0-256_256-512_433-434
# 	From worker 6:	From worker 6: processing block in global range: 256-512_256-512_433-434
# 	From worker 6:	From worker 6: processing block in global range: 256-512_0-256_468-469
# 	From worker 7:	From worker 7: processing block in global range: 256-512_256-512_367-368
# 	From worker 7:	From worker 7: processing block in global range: 0-256_0-256_368-369
# 	From worker 7:	From worker 7: processing block in global range: 256-512_0-256_368-369
# 	From worker 7:	From worker 7: processing block in global range: 0-256_256-512_368-369
# 	From worker 7:	From worker 7: processing block in global range: 256-512_256-512_368-369
# 	From worker 7:	From worker 7: processing block in global range: 0-256_0-256_369-370
# 	From worker 7:	From worker 7: processing block in global range: 256-512_0-256_369-370
# 	From worker 7:	From worker 7: processing block in global range: 0-256_256-512_369-370
# 	From worker 7:	From worker 7: processing block in global range: 256-512_256-512_369-370
# 	From worker 7:	From worker 7: processing block in global range: 0-256_0-256_370-371
# 	From worker 7:	From worker 7: processing block in global range: 256-512_0-256_370-371
# 	From worker 7:	From worker 7: processing block in global range: 0-256_256-512_370-371
# 	From worker 7:	From worker 7: processing block in global range: 0-256_256-512_495-496
# 	From worker 7:	From worker 7: processing block in global range: 256-512_256-512_507-508
# 	From worker 7:	From worker 7: processing block in global range: 0-256_256-512_511-512
# 	From worker 11:	From worker 11: processing block in global range: 256-512_256-512_400-401
# 	From worker 11:	From worker 11: processing block in global range: 0-256_0-256_401-402
# 	From worker 11:	From worker 11: processing block in global range: 256-512_0-256_401-402
# 	From worker 11:	From worker 11: processing block in global range: 0-256_256-512_401-402
# 	From worker 11:	From worker 11: processing block in global range: 0-256_256-512_404-405
# 	From worker 11:	From worker 11: processing block in global range: 256-512_256-512_404-405
# 	From worker 11:	From worker 11: processing block in global range: 0-256_0-256_405-406
# 	From worker 11:	From worker 11: processing block in global range: 256-512_0-256_405-406
# 	From worker 11:	From worker 11: processing block in global range: 256-512_256-512_466-467
# 	From worker 11:	From worker 11: processing block in global range: 0-256_0-256_467-468
# 	From worker 11:	From worker 11: processing block in global range: 256-512_0-256_467-468
# 	From worker 11:	From worker 11: processing block in global range: 0-256_256-512_467-468
# 	From worker 11:	From worker 11: processing block in global range: 256-512_256-512_467-468
# 	From worker 11:	From worker 11: processing block in global range: 0-256_0-256_468-469
# 	From worker 11:	From worker 11: processing block in global range: 0-256_256-512_484-485
# 	From worker 11:	From worker 11: processing block in global range: 0-256_256-512_496-497
# 	From worker 3:	From worker 3: processing block in global range: 0-256_0-256_169-170
# 	From worker 3:	From worker 3: processing block in global range: 256-512_0-256_169-170
# 	From worker 6:	From worker 6: processing block in global range: 0-256_256-512_468-469
# 	From worker 6:	From worker 6: processing block in global range: 256-512_256-512_496-497
# 	From worker 6:	From worker 6: processing block in global range: 0-256_0-256_497-498
# 	From worker 6:	From worker 6: processing block in global range: 256-512_0-256_497-498
# 	From worker 6:	From worker 6: processing block in global range: 0-256_256-512_497-498
# 	From worker 6:	From worker 6: processing block in global range: 256-512_256-512_497-498
# 	From worker 6:	From worker 6: processing block in global range: 0-256_0-256_498-499
# 	From worker 6:	From worker 6: processing block in global range: 256-512_0-256_498-499
# 	From worker 6:	From worker 6: processing block in global range: 0-256_256-512_498-499

# %%
plot(map(string, chunkSizeList), hcat(ss_list2, sc_list2), m=(8,:auto), legend=true,
        lab=["saving", "cutout"],
        xlabel="chunk size", 
        ylabel="speed (MB/s)")
