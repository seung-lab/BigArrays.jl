# %%
using BigArrays
using BigArrays.H5sBigArrays

ba = H5sBigArray("/usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap");
# Out:
# configDict = Dict{Symbol,Any}(Pair{Symbol,Any}(:globalOffset,Any[0,0,0,0]),Pair{Symbol,Any}(:chunkSize,Any[256,256,32,3]),Pair{Symbol,Any}(:compression,"deflate"),Pair{Symbol,Any}(:h5FilePrefix,"block_"),Pair{Symbol,Any}(:blockSize,Any[1024,1024,128,3]))
# WARNING: Base.CPU_CORES is deprecated.
#   likely near In[1]:1
# in blosc_filter at /usr/people/jingpeng/.julia/v0.5/HDF5/src/blosc_filter.jl
# WARNING: Base.CPU_CORES is deprecated.
#   likely near In[1]:1
# in blosc_filter at /usr/people/jingpeng/.julia/v0.5/HDF5/src/blosc_filter.jl

# %%
aff = ba[30769:30769+400,24577:24577+400,16384+1:16384+1250,1];
# Out:
# H5SBIGARRAY_DIRECTORY = "/usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap"
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((30769,24577,16385,1)),CartesianIndex{4}((31169,24977,16512,1)))
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((30769,24577,16385,1)),CartesianIndex{4}((31169,24977,16512,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((49,1,1,1)),CartesianIndex{4}((449,401,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_30721-31744_24577-25600_16385-16512_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,1,1)),CartesianIndex{4}((401,401,128,1))) ...
# ur = (1:401,1:401,1:128,1:1)
# globalRange =
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((30769,24577,16513,1)),CartesianIndex{4}((31169,24977,16640,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((49,1,1,1)),CartesianIndex{4}((449,401,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_30721-31744_24577-25600_16513-16640_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,129,1)),CartesianIndex{4}((401,401,256,1))) ...
# CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((30769,24577,16513,1)),CartesianIndex{4}((31169,24977,16640,1)))
# ur = (1:401,1:401,129:256,1:1)
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((30769,24577,16641,1)),CartesianIndex{4}((31169,24977,16768,1)))
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((30769,24577,16641,1)),CartesianIndex{4}((31169,24977,16768,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((49,1,1,1)),CartesianIndex{4}((449,401,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_30721-31744_24577-25600_16641-16768_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,257,1)),CartesianIndex{4}((401,401,384,1))) ...
# ur = (1:401,1:401,257:384,1:1)
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((30769,24577,16769,1)),CartesianIndex{4}((31169,24977,16896,1)))
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((30769,24577,16769,1)),CartesianIndex{4}((31169,24977,16896,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((49,1,1,1)),CartesianIndex{4}((449,401,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_30721-31744_24577-25600_16769-16896_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,385,1)),CartesianIndex{4}((401,401,512,1))) ...
# ur = (1:401,1:401,385:512,1:1)
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((30769,24577,16897,1)),CartesianIndex{4}((31169,24977,17024,1)))
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((30769,24577,16897,1)),CartesianIndex{4}((31169,24977,17024,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((49,1,1,1)),CartesianIndex{4}((449,401,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_30721-31744_24577-25600_16897-17024_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,513,1)),CartesianIndex{4}((401,401,640,1))) ...
# ur = (1:401,1:401,513:640,1:1)
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((30769,24577,17025,1)),CartesianIndex{4}((31169,24977,17152,1)))
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((30769,24577,17025,1)),CartesianIndex{4}((31169,24977,17152,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((49,1,1,1)),CartesianIndex{4}((449,401,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_30721-31744_24577-25600_17025-17152_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,641,1)),CartesianIndex{4}((401,401,768,1))) ...
# ur = (1:401,1:401,641:768,1:1)
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((30769,24577,17153,1)),CartesianIndex{4}((31169,24977,17280,1)))
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((30769,24577,17153,1)),CartesianIndex{4}((31169,24977,17280,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((49,1,1,1)),CartesianIndex{4}((449,401,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_30721-31744_24577-25600_17153-17280_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,769,1)),CartesianIndex{4}((401,401,896,1))) ...
# ur = (1:401,1:401,769:896,1:1)
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((30769,24577,17281,1)),CartesianIndex{4}((31169,24977,17408,1)))
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((30769,24577,17281,1)),CartesianIndex{4}((31169,24977,17408,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((49,1,1,1)),CartesianIndex{4}((449,401,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_30721-31744_24577-25600_17281-17408_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,897,1)),CartesianIndex{4}((401,401,1024,1))) ...
# ur = (1:401,1:401,897:1024,1:1)
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((30769,24577,17409,1)),CartesianIndex{4}((31169,24977,17536,1)))
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((30769,24577,17409,1)),CartesianIndex{4}((31169,24977,17536,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((49,1,1,1)),CartesianIndex{4}((449,401,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_30721-31744_24577-25600_17409-17536_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,1025,1)),CartesianIndex{4}((401,401,1152,1))) ...
# ur = (1:401,1:401,1025:1152,1:1)
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((30769,24577,17537,1)),CartesianIndex{4}((31169,24977,17634,1)))
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((30769,24577,17537,1)),CartesianIndex{4}((31169,24977,17634,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((49,1,1,1)),CartesianIndex{4}((449,401,98,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_30721-31744_24577-25600_17537-17664_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,1153,1)),CartesianIndex{4}((401,401,1250,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_30721-31744_24577-25600_17537-17664_1-3.h5

# %%
using Images
using Interact
@manipulate for z = 1:size(aff,3)
    img = Image(aff[:,:,z,1], colorspace="Gray", spatialorder=["x","y"])
end
# Out:
# WARNING: readall is deprecated, use readstring instead.
#  in depwarn(::String, ::Symbol) at ./deprecated.jl:64
#  in readall(::String, ::Vararg{String
# <div id="interact-js-shim">
#     <script charset="utf-8">
# (function (IPython, $, _, MathJax) {
#     $.event.special.destroyed = {
# 	remove: function(o) {
# 	    if (o.handler) {
# 		o.handler.apply(this, arguments)
# 	    }
# 	}
#     }
#
#     var OutputArea = IPython.version >= "4.0.0" ? require("notebook/js/outputarea").OutputArea : IPython.OutputArea;
#
#     var redrawValue = function (container, type, val) {
# 	var selector = $("<div/>");
# 	var oa = new OutputArea(_.extend(selector, {
# 	    selector: selector,
# 	    prompt_area: true,
# 	    events: IPython.events,
# 	    keyboard_manager: IPython.keyboard_manager
# 	})); // Hack to work with IPython 2.1.0
#
# 	switch (type) {
# 	case "image/png":
#             var _src = 'data:' + type + ';base64,' + val;
# 	    $(container).find("img").attr('src', _src);
# 	    break;
# 	default:
# 	    var toinsert = OutputArea.append_map[type].apply(
# 		oa, [val, {}, selector]
# 	    );
# 	    $(container).empty().append(toinsert.contents());
# 	    selector.remove();
# 	}
# 	if (type === "text/latex" && MathJax) {
# 	    MathJax.Hub.Queue(["Typeset", MathJax.Hub, toinsert.get(0)]);
# 	}
#     }
#
#
#     $(document).ready(function() {
# 	function initComm(evt, data) {
# 	    var comm_manager = data.kernel.comm_manager;
#         //_.extend(comm_manager.targets, require("widgets/js/widget"))
# 	    comm_manager.register_target("Signal", function (comm) {
#             comm.on_msg(function (msg) {
#                 //Widgets.log("message received", msg);
#                 var val = msg.content.data.value;
#                 $(".signal-" + comm.comm_id).each(function() {
#                 var type = $(this).data("type");
#                 if (val[type]) {
#                     redrawValue(this, type, val[type], type);
#                 }
#                 });
#                 delete val;
#                 delete msg.content.data.value;
#             });
# 	    });
#
# 	    // coordingate with Comm and redraw Signals
# 	    // XXX: Test using Reactive here to improve performance
# 	    $([IPython.events]).on(
# 		'output_appended.OutputArea', function (event, type, value, md, toinsert) {
# 		    if (md && md.reactive) {
#                 // console.log(md.comm_id);
#                 toinsert.addClass("signal-" + md.comm_id);
#                 toinsert.data("type", type);
#                 // Signal back indicating the mimetype required
#                 var comm_manager = IPython.notebook.kernel.comm_manager;
#                 var comm = comm_manager.comms[md.comm_id];
#                 comm.then(function (c) {
#                     c.send({action: "subscribe_mime",
#                        mime: type});
#                     toinsert.bind("destroyed", function() {
#                         c.send({action: "unsubscribe_mime",
#                                mime: type});
#                     });
#                 })
# 		    }
# 	    });
# 	}
#
# 	try {
# 	    // try to initialize right away. otherwise, wait on the status_started event.
# 	    initComm(undefined, IPython.notebook);
# 	} catch (e) {
# 	    $([IPython.events]).on('kernel_created.Kernel kernel_created.Session', initComm);
# 	}
#     });
# })(IPython, jQuery, _, MathJax);
# </script>
#     <script>
#         window.interactLoadedFlag = true
#        $("#interact-js-shim").bind("destroyed", function () {
#            if (window.interactLoadedFlag) {
#                console.warn("JavaScript required by Interact will be removed if you remove this cell or run using Interact more than once.")
#            }
#        })
#        $([IPython.events]).on("kernel_starting.Kernel kernel_restarting.Kernel", function () { window.interactLoadedFlag = false })
#    </script>
# </div>
# Interact.Slider{Int64}(Signal{Int64}(625, nactions=0),"z",625,1:1250,true)
# ,N}) at ./deprecated.jl:30
#  in include_from_node1(::String) at ./loading.jl:488
#  in __init__() at /usr/people/jingpeng/.julia/v0.5/Interact/src/Interact.jl:81
#  in include_from_node1(::String) at ./loading.jl:488
#  in eval(::Module, ::Any) at ./boot.jl:234
#  in require(::Symbol) at ./loading.jl:415
#  in include_string(::String, ::String) at ./loading.jl:441
#  in execute_request(::ZMQ.Socket, ::IJulia.Msg) at /usr/people/jingpeng/.julia/v0.5/IJulia/src/execute_request.jl:169
#  in eventloop(::ZMQ.Socket) at /usr/people/jingpeng/.julia/v0.5/IJulia/src/eventloop.jl:8
#  in (::IJulia.##9#15)() at ./task.jl:360
# while loading /usr/people/jingpeng/.julia/v0.5/Interact/src/IJulia/setup.jl, in expression starting on line 13
# WARNING: Base.writemime is deprecated.
#   likely near /usr/people/jingpeng/.julia/v0.5/Interact/src/IJulia/setup.jl:105
# WARNING: Base.writemime is deprecated.
#   likely near /usr/people/jingpeng/.julia/v0.5/Interact/src/IJulia/setup.jl:105
# WARNING: Base.writemime is deprecated.
#   likely near /usr/people/jingpeng/.julia/v0.5/Interact/src/IJulia/setup.jl:109
# WARNING: Base.writemime is deprecated.
#   likely near /usr/people/jingpeng/.julia/v0.5/Interact/src/IJulia/setup.jl:109
# WARNING: Base.writemime is deprecated.
#   likely near /usr/people/jingpeng/.julia/v0.5/Interact/src/IJulia/setup.jl:113
# WARNING: Base.writemime is deprecated.
#   likely near /usr/people/jingpeng/.julia/v0.5/Interact/src/IJulia/setup.jl:113
# WARNING: Base.writemime is deprecated.
#   likely near /usr/people/jingpeng/.julia/v0.5/Interact/src/IJulia/setup.jl:118
# WARNING: Base.writemime is deprecated.
#   likely near /usr/people/jingpeng/.julia/v0.5/Interact/src/IJulia/setup.jl:118
# WARNING: Base.writemime is deprecated.
#   likely near /usr/people/jingpeng/.julia/v0.5/Interact/src/IJulia/setup.jl:123
# WARNING: Base.writemime is deprecated.
#   likely near /usr/people/jingpeng/.julia/v0.5/Interact/src/IJulia/setup.jl:123
# Gray Images.Image with:
#   data: 401×401 Array{Float32,2}
#   properties:
#     colorspace: Gray
#     spatialorder:  x y

# %%
# aff
boundingbox(ba)
# Out:
# H5SBIGARRAY_DIRECTORY = "/usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap"
# start = [14337,18433,16385,1]
# start = [14337,19457,16385,1]
# start = [14337,19457,16513,1]
# start = [14337,20481,16385,1]
# start = [14337,20481,16513,1]
# start = [14337,21505,16385,1]
# start = [14337,21505,16513,1]
# start = [14337,21505,16641,1]
# start = [14337,22529,16385,1]
# start = [14337,22529,16513,1]
# start = [14337,23553,16385,1]
# start = [14337,23553,16513,1]
# start = [14337,23553,16641,1]
# start = [14337,24577,16385,1]
# start = [14337,24577,16513,1]
# start = [14337,25601,16385,1]
# start = [14337,25601,16513,1]
# start = [14337,26625,16385,1]
# start = [14337,26625,16513,1]
# start = [15361,18433,16385,1]
# start = [15361,19457,16385,1]
# start = [15361,19457,16513,1]
# start = [15361,19457,16641,1]
# start = [15361,20481,16385,1]
# start = [15361,20481,16513,1]
# start = [15361,20481,16641,1]
# start = [15361,21505,16385,1]
# start = [15361,21505,16513,1]
# start = [15361,22529,16385,1]
# start = [15361,22529,16513,1]
# start = [15361,23553,16385,1]
# start = [15361,23553,16513,1]
# start = [15361,23553,16641,1]
# start = [15361,24577,16385,1]
# start = [15361,24577,16513,1]
# start = [15361,25601,16385,1]
# start = [15361,25601,16513,1]
# start = [15361,25601,16641,1]
# start = [15361,26625,16385,1]
# start = [15361,26625,16513,1]
# start = [15361,26625,16641,1]
# start = [15361,27649,16385,1]
# start = [15361,27649,16513,1]
# start = [16385,18433,16385,1]
# start = [16385,18433,16513,1]
# start = [16385,19457,16385,1]
# start = [16385,19457,16513,1]
# start = [16385,20481,16385,1]
# start = [16385,20481,16513,1]
# start = [16385,21505,16385,1]
# start = [16385,21505,16513,1]
# start = [16385,22529,16385,1]
# start = [16385,22529,16513,1]
# start = [16385,22529,16641,1]
# start = [16385,23553,16385,1]
# start = [16385,23553,16513,1]
# start = [16385,24577,16385,1]
# start = [16385,24577,16513,1]
# start = [16385,24577,16641,1]
# start = [16385,25601,16385,1]
# start = [16385,25601,16513,1]
# start = [16385,25601,16641,1]
# start = [16385,26625,16385,1]
# start = [16385,26625,16513,1]
# start = [16385,27649,16513,1]
# start = [16385,27649,16641,1]
# start = [17409,17409,16385,1]
# start = [17409,18433,16385,1]
# start = [17409,18433,16513,1]
# start = [17409,19457,16385,1]
# start = [17409,19457,16513,1]
# start = [17409,20481,16385,1]
# start = [17409,20481,16513,1]
# start = [17409,20481,16641,1]
# start = [17409,21505,16385,1]
# start = [17409,21505,16513,1]
# start = [17409,21505,16641,1]
# start = [17409,22529,16385,1]
# start = [17409,22529,16513,1]
# start = [17409,23553,16385,1]
# start = [17409,23553,16513,1]
# start = [17409,23553,16641,1]
# start = [17409,24577,16385,1]
# start = [17409,24577,16513,1]
# start = [17409,25601,16385,1]
# start = [17409,25601,16513,1]
# start = [17409,25601,16641,1]
# start = [17409,26625,16385,1]
# start = [17409,26625,16513,1]
# start = [17409,27649,16513,1]
# start = [17409,27649,16641,1]
# start = [18433,17409,16385,1]
# start = [18433,18433,16385,1]
# start = [18433,18433,16513,1]
# start = [18433,19457,16385,1]
# start = [18433,19457,16513,1]
# start = [18433,20481,16385,1]
# start = [18433,20481,16513,1]
# start = [18433,20481,16641,1]
# start = [18433,21505,16385,1]
# start = [18433,21505,16513,1]
# start = [18433,22529,16385,1]
# start = [18433,22529,16513,1]
# start = [18433,23553,16385,1]
# start = [18433,23553,16513,1]
# start = [18433,24577,16385,1]
# start = [18433,24577,16513,1]
# start = [18433,25601,16385,1]
# start = [18433,25601,16513,1]
# start = [18433,25601,16641,1]
# start = [18433,26625,16385,1]
# start = [18433,26625,16641,1]
# start = [18433,27649,16513,1]
# start = [18433,27649,16641,1]
# start = [19457,17409,16385,1]
# start = [19457,18433,16385,1]
# start = [19457,18433,16513,1]
# start = [19457,18433,16641,1]
# start = [19457,19457,16385,1]
# start = [19457,19457,16513,1]
# start = [19457,19457,16641,1]
# start = [19457,20481,16385,1]
# start = [19457,20481,16513,1]
# start = [19457,20481,16641,1]
# start = [19457,21505,16385,1]
# start = [19457,21505,16513,1]
# start = [19457,21505,16641,1]
# start = [19457,22529,16385,1]
# start = [19457,22529,16513,1]
# start = [19457,23553,16385,1]
# start = [19457,23553,16513,1]
# start = [19457,23553,16641,1]
# start = [19457,24577,16385,1]
# start = [19457,24577,16513,1]
# start = [19457,25601,16385,1]
# start = [19457,25601,16513,1]
# start = [19457,26625,16385,1]
# start = [19457,26625,16513,1]
# start = [19457,26625,16641,1]
# start = [19457,27649,16513,1]
# start = [19457,27649,16641,1]
# start = [20481,17409,16385,1]
# start = [20481,18433,16385,1]
# start = [20481,18433,16513,1]
# start = [20481,19457,16385,1]
# start = [20481,19457,16513,1]
# start = [20481,19457,16641,1]
# start = [20481,20481,16385,1]
# start = [20481,20481,16513,1]
# start = [20481,20481,16641,1]
# start = [20481,21505,16385,1]
# start = [20481,21505,16513,1]
# start = [20481,22529,16385,1]
# start = [20481,23553,16385,1]
# start = [20481,23553,16513,1]
# start = [20481,23553,16641,1]
# start = [20481,24577,16385,1]
# start = [20481,24577,16513,1]
# start = [20481,25601,16385,1]
# start = [20481,25601,16513,1]
# start = [20481,25601,16641,1]
# start = [20481,26625,16385,1]
# start = [20481,26625,16513,1]
# start = [20481,26625,16641,1]
# start = [20481,27649,16641,1]
# start = [21505,17409,16385,1]
# start = [21505,18433,16385,1]
# start = [21505,18433,16513,1]
# start = [21505,18433,16641,1]
# start = [21505,18433,16769,1]
# start = [21505,19457,16385,1]
# start = [21505,19457,16513,1]
# start = [21505,19457,16641,1]
# start = [21505,19457,16769,1]
# start = [21505,20481,16385,1]
# start = [21505,20481,16769,1]
# start = [21505,21505,16385,1]
# start = [21505,21505,16513,1]
# start = [21505,21505,16641,1]
# start = [21505,21505,16769,1]
# start = [21505,22529,16385,1]
# start = [21505,22529,16513,1]
# start = [21505,22529,16641,1]
# start = [21505,22529,16769,1]
# start = [21505,23553,16385,1]
# start = [21505,23553,16513,1]
# start = [21505,23553,16769,1]
# start = [21505,24577,16385,1]
# start = [21505,24577,16513,1]
# start = [21505,24577,16641,1]
# start = [21505,24577,16769,1]
# start = [21505,25601,16385,1]
# start = [21505,25601,16513,1]
# start = [21505,25601,16769,1]
# start = [21505,26625,16385,1]
# start = [21505,26625,16513,1]
# start = [21505,26625,16769,1]
# start = [21505,27649,16385,1]
# start = [21505,27649,16513,1]
# start = [21505,27649,16769,1]
# start = [21505,28673,16385,1]
# start = [21505,29697,16385,1]
# start = [21505,30721,16385,1]
# start = [21505,31745,16385,1]
# start = [21505,32769,16385,1]
# start = [22529,17409,16385,1]
# start = [22529,18433,16385,1]
# start = [22529,18433,16513,1]
# start = [22529,18433,16641,1]
# start = [22529,18433,16769,1]
# start = [22529,19457,16385,1]
# start = [22529,19457,16513,1]
# start = [22529,19457,16641,1]
# start = [22529,19457,16769,1]
# start = [22529,20481,16385,1]
# start = [22529,20481,16513,1]
# start = [22529,20481,16641,1]
# start = [22529,20481,16769,1]
# start = [22529,21505,16385,1]
# start = [22529,21505,16513,1]
# start = [22529,21505,16769,1]
# start = [22529,22529,16385,1]
# start = [22529,22529,16513,1]
# start = [22529,22529,16641,1]
# start = [22529,22529,16769,1]
# start = [22529,23553,16385,1]
# start = [22529,23553,16513,1]
# start = [22529,23553,16769,1]
# start = [22529,24577,16385,1]
# start = [22529,24577,16513,1]
# start = [22529,24577,16769,1]
# start = [22529,25601,16385,1]
# start = [22529,25601,16513,1]
# start = [22529,25601,16641,1]
# start = [22529,25601,16769,1]
# start = [22529,26625,16385,1]
# start = [22529,26625,16513,1]
# start = [22529,26625,16769,1]
# start = [22529,27649,16385,1]
# start = [22529,27649,16513,1]
# start = [22529,27649,16641,1]
# start = [22529,27649,16769,1]
# start = [22529,28673,16385,1]
# start = [22529,28673,16513,1]
# start = [22529,28673,16641,1]
# start = [22529,29697,16385,1]
# start = [22529,29697,16513,1]
# start = [22529,29697,16641,1]
# start = [22529,30721,16385,1]
# start = [22529,30721,16513,1]
# start = [22529,30721,16641,1]
# start = [22529,31745,16385,1]
# start = [22529,31745,16513,1]
# start = [22529,31745,16641,1]
# start = [22529,32769,16385,1]
# start = [22529,32769,16641,1]
# start = [22529,33793,16385,1]
# start = [22529,33793,16513,1]
# start = [23553,17409,16385,1]
# start = [23553,18433,16385,1]
# start = [23553,18433,16513,1]
# start = [23553,18433,16641,1]
# start = [23553,18433,16769,1]
# start = [23553,19457,16385,1]
# start = [23553,19457,16513,1]
# start = [23553,19457,16641,1]
# start = [23553,19457,16769,1]
# start = [23553,19457,16897,1]
# start = [23553,20481,16385,1]
# start = [23553,20481,16513,1]
# start = [23553,20481,16641,1]
# start = [23553,20481,16769,1]
# start = [23553,21505,16385,1]
# start = [23553,21505,16513,1]
# start = [23553,21505,16769,1]
# start = [23553,22529,16385,1]
# start = [23553,22529,16513,1]
# start = [23553,22529,16641,1]
# start = [23553,22529,16769,1]
# start = [23553,22529,16897,1]
# start = [23553,23553,16385,1]
# start = [23553,23553,16513,1]
# start = [23553,23553,16769,1]
# start = [23553,24577,16385,1]
# start = [23553,24577,16513,1]
# start = [23553,24577,16769,1]
# start = [23553,25601,16385,1]
# start = [23553,25601,16513,1]
# start = [23553,25601,16769,1]
# start = [23553,26625,16385,1]
# start = [23553,26625,16513,1]
# start = [23553,26625,16641,1]
# start = [23553,26625,16769,1]
# start = [23553,27649,16385,1]
# start = [23553,27649,16513,1]
# start = [23553,27649,16641,1]
# start = [23553,27649,16769,1]
# start = [23553,28673,16385,1]
# start = [23553,28673,16513,1]
# start = [23553,29697,16385,1]
# start = [23553,29697,16513,1]
# start = [23553,29697,16641,1]
# start = [23553,30721,16385,1]
# start = [23553,30721,16513,1]
# start = [23553,31745,16385,1]
# start = [23553,31745,16513,1]
# start = [23553,31745,16641,1]
# start = [23553,32769,16385,1]
# start = [23553,32769,16513,1]
# start = [23553,33793,16385,1]
# start = [23553,33793,16513,1]
# start = [23553,33793,16641,1]
# start = [24577,17409,16385,1]
# start = [24577,18433,16385,1]
# start = [24577,18433,16513,1]
# start = [24577,18433,16641,1]
# start = [24577,18433,16769,1]
# start = [24577,19457,16385,1]
# start = [24577,19457,16513,1]
# start = [24577,19457,16641,1]
# start = [24577,19457,16769,1]
# start = [24577,19457,16897,1]
# start = [24577,20481,16385,1]
# start = [24577,20481,16513,1]
# start = [24577,20481,16769,1]
# start = [24577,21505,16385,1]
# start = [24577,21505,16513,1]
# start = [24577,21505,16641,1]
# start = [24577,21505,16769,1]
# start = [24577,21505,16897,1]
# start = [24577,22529,16385,1]
# start = [24577,22529,16513,1]
# start = [24577,22529,16641,1]
# start = [24577,22529,16769,1]
# start = [24577,23553,16385,1]
# start = [24577,23553,16513,1]
# start = [24577,23553,16641,1]
# start = [24577,23553,16769,1]
# start = [24577,23553,16897,1]
# start = [24577,24577,16385,1]
# start = [24577,24577,16513,1]
# start = [24577,24577,16769,1]
# start = [24577,24577,16897,1]
# start = [24577,25601,16385,1]
# start = [24577,25601,16513,1]
# start = [24577,25601,16769,1]
# start = [24577,26625,16385,1]
# start = [24577,26625,16513,1]
# start = [24577,26625,16641,1]
# start = [24577,26625,16769,1]
# start = [24577,26625,16897,1]
# start = [24577,27649,16385,1]
# start = [24577,27649,16513,1]
# start = [24577,27649,16641,1]
# start = [24577,27649,16769,1]
# start = [24577,28673,16385,1]
# start = [24577,28673,16513,1]
# start = [24577,28673,16641,1]
# start = [24577,29697,16385,1]
# start = [24577,29697,16513,1]
# start = [24577,30721,16385,1]
# start = [24577,30721,16513,1]
# start = [24577,30721,16641,1]
# start = [24577,31745,16385,1]
# start = [24577,31745,16513,1]
# start = [24577,31745,16641,1]
# start = [24577,32769,16385,1]
# start = [24577,32769,16513,1]
# start = [24577,33793,16385,1]
# start = [24577,33793,16513,1]
# start = [25601,17409,16385,1]
# start = [25601,18433,16385,1]
# start = [25601,18433,16513,1]
# start = [25601,18433,16641,1]
# start = [25601,18433,16769,1]
# start = [25601,19457,16385,1]
# start = [25601,19457,16513,1]
# start = [25601,19457,16641,1]
# start = [25601,19457,16769,1]
# start = [25601,19457,16897,1]
# start = [25601,20481,16385,1]
# start = [25601,20481,16513,1]
# start = [25601,20481,16769,1]
# start = [25601,20481,16897,1]
# start = [25601,21505,16385,1]
# start = [25601,21505,16513,1]
# start = [25601,21505,16769,1]
# start = [25601,22529,16385,1]
# start = [25601,22529,16513,1]
# start = [25601,22529,16641,1]
# start = [25601,22529,16769,1]
# start = [25601,22529,16897,1]
# start = [25601,23553,16385,1]
# start = [25601,23553,16513,1]
# start = [25601,23553,16769,1]
# start = [25601,23553,16897,1]
# start = [25601,24577,16385,1]
# start = [25601,24577,16513,1]
# start = [25601,24577,16641,1]
# start = [25601,24577,16769,1]
# start = [25601,25601,16385,1]
# start = [25601,25601,16513,1]
# start = [25601,25601,16769,1]
# start = [25601,25601,16897,1]
# start = [25601,26625,16385,1]
# start = [25601,26625,16513,1]
# start = [25601,26625,16769,1]
# start = [25601,27649,16385,1]
# start = [25601,27649,16513,1]
# start = [25601,27649,16641,1]
# start = [25601,27649,16769,1]
# start = [25601,27649,16897,1]
# start = [25601,28673,16385,1]
# start = [25601,28673,16513,1]
# start = [25601,28673,16641,1]
# start = [25601,29697,16385,1]
# start = [25601,29697,16513,1]
# start = [25601,29697,16641,1]
# start = [25601,30721,16385,1]
# start = [25601,30721,16641,1]
# start = [25601,31745,16385,1]
# start = [25601,31745,16513,1]
# start = [25601,31745,16641,1]
# start = [25601,32769,16385,1]
# start = [25601,32769,16641,1]
# start = [25601,33793,16385,1]
# start = [25601,33793,16513,1]
# start = [25601,33793,16641,1]
# start = [26625,17409,16385,1]
# start = [26625,18433,16385,1]
# start = [26625,18433,16513,1]
# start = [26625,18433,16769,1]
# start = [26625,18433,16897,1]
# start = [26625,19457,16385,1]
# start = [26625,19457,16513,1]
# start = [26625,19457,16641,1]
# start = [26625,19457,16769,1]
# start = [26625,19457,16897,1]
# start = [26625,20481,16385,1]
# start = [26625,20481,16513,1]
# start = [26625,20481,16641,1]
# start = [26625,20481,16769,1]
# start = [26625,21505,16385,1]
# start = [26625,21505,16513,1]
# start = [26625,21505,16641,1]
# start = [26625,21505,16769,1]
# start = [26625,21505,16897,1]
# start = [26625,22529,16385,1]
# start = [26625,22529,16513,1]
# start = [26625,22529,16769,1]
# start = [26625,22529,16897,1]
# start = [26625,23553,16385,1]
# start = [26625,23553,16513,1]
# start = [26625,23553,16641,1]
# start = [26625,23553,16769,1]
# start = [26625,24577,16385,1]
# start = [26625,24577,16513,1]
# start = [26625,24577,16769,1]
# start = [26625,24577,16897,1]
# start = [26625,25601,16385,1]
# start = [26625,25601,16513,1]
# start = [26625,25601,16641,1]
# start = [26625,25601,16769,1]
# start = [26625,26625,16385,1]
# start = [26625,26625,16513,1]
# start = [26625,26625,16641,1]
# start = [26625,26625,16769,1]
# start = [26625,27649,16385,1]
# start = [26625,27649,16513,1]
# start = [26625,27649,16641,1]
# start = [26625,27649,16897,1]
# start = [26625,28673,16385,1]
# start = [26625,28673,16513,1]
# start = [26625,28673,16641,1]
# start = [26625,29697,16385,1]
# start = [26625,29697,16513,1]
# start = [26625,29697,16641,1]
# start = [26625,30721,16385,1]
# start = [26625,30721,16513,1]
# start = [26625,30721,16641,1]
# start = [26625,31745,16385,1]
# start = [26625,31745,16513,1]
# start = [26625,32769,16385,1]
# start = [26625,32769,16513,1]
# start = [26625,33793,16385,1]
# start = [26625,33793,16641,1]
# start = [27649,17409,16385,1]
# start = [27649,18433,16385,1]
# start = [27649,18433,16513,1]
# start = [27649,18433,16641,1]
# start = [27649,18433,16769,1]
# start = [27649,19457,16385,1]
# start = [27649,19457,16513,1]
# start = [27649,19457,16769,1]
# start = [27649,19457,16897,1]
# start = [27649,20481,16385,1]
# start = [27649,20481,16513,1]
# start = [27649,20481,16769,1]
# start = [27649,21505,16385,1]
# start = [27649,21505,16513,1]
# start = [27649,21505,16641,1]
# start = [27649,21505,16769,1]
# start = [27649,21505,16897,1]
# start = [27649,22529,16385,1]
# start = [27649,22529,16513,1]
# start = [27649,22529,16641,1]
# start = [27649,22529,16769,1]
# start = [27649,23553,16385,1]
# start = [27649,23553,16513,1]
# start = [27649,23553,16769,1]
# start = [27649,23553,16897,1]
# start = [27649,24577,16385,1]
# start = [27649,24577,16513,1]
# start = [27649,24577,16769,1]
# start = [27649,25601,16385,1]
# start = [27649,25601,16513,1]
# start = [27649,25601,16769,1]
# start = [27649,26625,16385,1]
# start = [27649,26625,16513,1]
# start = [27649,26625,16769,1]
# start = [27649,27649,16385,1]
# start = [27649,27649,16513,1]
# start = [27649,28673,16385,1]
# start = [27649,28673,16513,1]
# start = [27649,28673,16641,1]
# start = [27649,29697,16385,1]
# start = [27649,29697,16513,1]
# start = [27649,29697,16641,1]
# start = [27649,30721,16385,1]
# start = [27649,30721,16513,1]
# start = [27649,30721,16641,1]
# start = [27649,31745,16385,1]
# start = [27649,31745,16513,1]
# start = [27649,32769,16385,1]
# start = [27649,32769,16513,1]
# start = [27649,32769,16641,1]
# start = [27649,33793,16385,1]
# start = [27649,33793,16513,1]
# start = [28673,17409,16385,1]
# start = [28673,18433,16385,1]
# start = [28673,18433,16513,1]
# start = [28673,18433,16769,1]
# start = [28673,19457,16385,1]
# start = [28673,19457,16513,1]
# start = [28673,19457,16769,1]
# start = [28673,20481,16385,1]
# start = [28673,20481,16513,1]
# start = [28673,20481,16641,1]
# start = [28673,20481,16769,1]
# start = [28673,20481,16897,1]
# start = [28673,21505,16385,1]
# start = [28673,21505,16513,1]
# start = [28673,21505,16641,1]
# start = [28673,21505,16769,1]
# start = [28673,22529,16385,1]
# start = [28673,22529,16513,1]
# start = [28673,22529,16769,1]
# start = [28673,23553,16385,1]
# start = [28673,23553,16513,1]
# start = [28673,23553,16641,1]
# start = [28673,23553,16769,1]
# start = [28673,24577,16385,1]
# start = [28673,24577,16513,1]
# start = [28673,24577,16769,1]
# start = [28673,24577,16897,1]
# start = [28673,25601,16385,1]
# start = [28673,25601,16513,1]
# start = [28673,25601,16641,1]
# start = [28673,25601,16769,1]
# start = [28673,26625,16385,1]
# start = [28673,26625,16513,1]
# start = [28673,26625,16769,1]
# start = [28673,27649,16385,1]
# start = [28673,27649,16513,1]
# start = [28673,27649,16641,1]
# start = [28673,27649,16769,1]
# start = [28673,28673,16385,1]
# start = [28673,28673,16513,1]
# start = [28673,28673,16641,1]
# start = [28673,28673,16769,1]
# start = [28673,29697,16385,1]
# start = [28673,29697,16769,1]
# start = [28673,30721,16385,1]
# start = [28673,30721,16513,1]
# start = [28673,30721,16641,1]
# start = [28673,30721,16769,1]
# start = [28673,31745,16385,1]
# start = [28673,31745,16513,1]
# start = [28673,31745,16641,1]
# start = [28673,31745,16769,1]
# start = [28673,32769,16385,1]
# start = [28673,32769,16513,1]
# start = [28673,32769,16641,1]
# start = [28673,32769,16769,1]
# start = [28673,33793,16385,1]
# start = [28673,33793,16513,1]
# start = [28673,33793,16769,1]
# start = [29697,17409,16385,1]
# start = [29697,17409,16897,1]
# start = [29697,18433,16385,1]
# start = [29697,18433,16513,1]
# start = [29697,18433,16769,1]
# start = [29697,18433,16897,1]
# start = [29697,19457,16385,1]
# start = [29697,19457,16513,1]
# start = [29697,19457,16769,1]
# start = [29697,19457,16897,1]
# start = [29697,20481,16385,1]
# start = [29697,20481,16769,1]
# start = [29697,21505,16385,1]
# start = [29697,21505,16513,1]
# start = [29697,21505,16641,1]
# start = [29697,21505,16769,1]
# start = [29697,21505,16897,1]
# start = [29697,22529,16385,1]
# start = [29697,22529,16513,1]
# start = [29697,22529,16641,1]
# start = [29697,22529,16769,1]
# start = [29697,22529,16897,1]
# start = [29697,23553,16385,1]
# start = [29697,23553,16513,1]
# start = [29697,23553,16641,1]
# start = [29697,23553,16769,1]
# start = [29697,24577,16385,1]
# start = [29697,24577,16513,1]
# start = [29697,24577,16769,1]
# start = [29697,25601,16385,1]
# start = [29697,25601,16513,1]
# start = [29697,25601,16769,1]
# start = [29697,26625,16385,1]
# start = [29697,26625,16513,1]
# start = [29697,26625,16641,1]
# start = [29697,26625,16769,1]
# start = [29697,27649,16385,1]
# start = [29697,27649,16513,1]
# start = [29697,27649,16769,1]
# start = [29697,28673,16385,1]
# start = [29697,28673,16513,1]
# start = [29697,28673,16641,1]
# start = [29697,28673,16769,1]
# start = [29697,29697,16385,1]
# start = [29697,29697,16513,1]
# start = [29697,29697,16769,1]
# start = [29697,30721,16385,1]
# start = [29697,30721,16513,1]
# start = [29697,30721,16641,1]
# start = [29697,30721,16769,1]
# start = [29697,31745,16385,1]
# start = [29697,31745,16513,1]
# start = [29697,31745,16641,1]
# start = [29697,31745,16769,1]
# start = [29697,32769,16385,1]
# start = [29697,32769,16513,1]
# start = [29697,32769,16769,1]
# start = [29697,33793,16385,1]
# start = [29697,33793,16513,1]
# start = [29697,33793,16641,1]
# start = [29697,33793,16769,1]
# start = [30721,17409,16385,1]
# start = [30721,18433,16385,1]
# start = [30721,18433,16513,1]
# start = [30721,18433,16769,1]
# start = [30721,18433,16897,1]
# start = [30721,19457,16385,1]
# start = [30721,19457,16513,1]
# start = [30721,19457,16769,1]
# start = [30721,19457,16897,1]
# start = [30721,20481,16385,1]
# start = [30721,20481,16513,1]
# start = [30721,20481,16769,1]
# start = [30721,21505,16385,1]
# start = [30721,21505,16513,1]
# start = [30721,21505,16769,1]
# start = [30721,22529,16385,1]
# start = [30721,22529,16513,1]
# start = [30721,22529,16641,1]
# start = [30721,22529,16769,1]
# start = [30721,22529,16897,1]
# start = [30721,23553,16385,1]
# start = [30721,23553,16513,1]
# start = [30721,23553,16769,1]
# start = [30721,23553,16897,1]
# start = [30721,24577,16385,1]
# start = [30721,24577,16513,1]
# start = [30721,24577,16769,1]
# start = [30721,25601,16385,1]
# start = [30721,25601,16513,1]
# start = [30721,25601,16641,1]
# start = [30721,25601,16769,1]
# start = [30721,26625,16385,1]
# start = [30721,26625,16513,1]
# start = [30721,26625,16769,1]
# start = [30721,26625,16897,1]
# start = [30721,27649,16385,1]
# start = [30721,27649,16513,1]
# start = [30721,27649,16769,1]
# start = [30721,28673,16385,1]
# start = [30721,28673,16513,1]
# start = [30721,28673,16769,1]
# start = [30721,29697,16385,1]
# start = [30721,29697,16513,1]
# start = [30721,29697,16641,1]
# start = [30721,29697,16769,1]
# start = [30721,30721,16385,1]
# start = [30721,30721,16513,1]
# start = [30721,30721,16641,1]
# start = [30721,30721,16769,1]
# start = [30721,31745,16385,1]
# start = [30721,31745,16513,1]
# start = [30721,31745,16641,1]
# start = [30721,31745,16769,1]
# start = [30721,32769,16385,1]
# start = [30721,32769,16513,1]
# start = [30721,32769,16769,1]
# start = [30721,33793,16385,1]
# start = [30721,33793,16513,1]
# start = [30721,33793,16641,1]
# start = [30721,33793,16769,1]
# start = [31745,17409,16385,1]
# start = [31745,17409,16897,1]
# start = [31745,18433,16385,1]
# start = [31745,18433,16513,1]
# start = [31745,18433,16641,1]
# start = [31745,18433,16769,1]
# start = [31745,18433,16897,1]
# start = [31745,19457,16385,1]
# start = [31745,19457,16513,1]
# start = [31745,19457,16769,1]
# start = [31745,19457,16897,1]
# start = [31745,20481,16385,1]
# start = [31745,20481,16513,1]
# start = [31745,20481,16641,1]
# start = [31745,20481,16769,1]
# start = [31745,20481,16897,1]
# start = [31745,21505,16385,1]
# start = [31745,21505,16513,1]
# start = [31745,21505,16641,1]
# start = [31745,21505,16769,1]
# start = [31745,21505,16897,1]
# start = [31745,22529,16385,1]
# start = [31745,22529,16513,1]
# start = [31745,22529,16769,1]
# start = [31745,23553,16385,1]
# start = [31745,23553,16513,1]
# start = [31745,23553,16641,1]
# start = [31745,23553,16769,1]
# start = [31745,23553,16897,1]
# start = [31745,24577,16385,1]
# start = [31745,24577,16513,1]
# start = [31745,24577,16641,1]
# start = [31745,24577,16769,1]
# start = [31745,24577,16897,1]
# start = [31745,25601,16385,1]
# start = [31745,25601,16513,1]
# start = [31745,25601,16769,1]
# start = [31745,26625,16385,1]
# start = [31745,26625,16513,1]
# start = [31745,26625,16769,1]
# start = [31745,27649,16385,1]
# start = [31745,27649,16513,1]
# start = [31745,27649,16641,1]
# start = [31745,27649,16769,1]
# start = [31745,28673,16385,1]
# start = [31745,28673,16513,1]
# start = [31745,28673,16641,1]
# start = [31745,28673,16769,1]
# start = [31745,29697,16385,1]
# start = [31745,29697,16641,1]
# start = [31745,29697,16769,1]
# start = [31745,30721,16385,1]
# start = [31745,30721,16513,1]
# start = [31745,30721,16769,1]
# start = [31745,31745,16385,1]
# start = [31745,31745,16513,1]
# start = [31745,31745,16769,1]
# start = [31745,32769,16385,1]
# start = [31745,32769,16513,1]
# start = [31745,32769,16641,1]
# start = [31745,32769,16769,1]
# start = [31745,33793,16385,1]
# start = [31745,33793,16641,1]
# start = [31745,33793,16769,1]
# start = [32769,17409,16385,1]
# start = [32769,17409,16897,1]
# start = [32769,18433,16385,1]
# start = [32769,18433,16513,1]
# start = [32769,18433,16641,1]
# start = [32769,18433,16769,1]
# start = [32769,18433,16897,1]
# start = [32769,19457,16385,1]
# start = [32769,19457,16513,1]
# start = [32769,19457,16769,1]
# start = [32769,19457,16897,1]
# start = [32769,20481,16385,1]
# start = [32769,20481,16513,1]
# start = [32769,20481,16641,1]
# start = [32769,20481,16769,1]
# start = [32769,20481,16897,1]
# start = [32769,21505,16385,1]
# start = [32769,21505,16513,1]
# start = [32769,21505,16769,1]
# start = [32769,21505,16897,1]
# start = [32769,22529,16385,1]
# start = [32769,22529,16513,1]
# start = [32769,22529,16769,1]
# start = [32769,23553,16385,1]
# start = [32769,23553,16513,1]
# start = [32769,23553,16641,1]
# start = [32769,23553,16769,1]
# start = [32769,24577,16385,1]
# start = [32769,24577,16513,1]
# start = [32769,24577,16769,1]
# start = [32769,25601,16385,1]
# start = [32769,25601,16513,1]
# start = [32769,25601,16641,1]
# start = [32769,25601,16769,1]
# start = [32769,26625,16385,1]
# start = [32769,26625,16513,1]
# start = [32769,26625,16769,1]
# start = [32769,27649,16385,1]
# start = [32769,27649,16513,1]
# start = [32769,27649,16641,1]
# start = [32769,27649,16769,1]
# start = [32769,28673,16385,1]
# start = [32769,28673,16513,1]
# start = [32769,28673,16769,1]
# start = [32769,28673,16897,1]
# start = [32769,29697,16385,1]
# start = [32769,29697,16513,1]
# start = [32769,29697,16641,1]
# start = [32769,29697,16769,1]
# start = [32769,30721,16385,1]
# start = [32769,30721,16513,1]
# start = [32769,30721,16769,1]
# start = [32769,31745,16385,1]
# start = [32769,31745,16513,1]
# start = [32769,31745,16641,1]
# start = [32769,31745,16769,1]
# start = [32769,32769,16385,1]
# start = [32769,32769,16513,1]
# start = [32769,32769,16641,1]
# start = [32769,32769,16769,1]
# start = [32769,33793,16385,1]
# start = [32769,33793,16513,1]
# start = [32769,33793,16641,1]
# start = [32769,33793,16769,1]
# start = [33793,17409,16385,1]
# start = [33793,17409,16897,1]
# start = [33793,18433,16385,1]
# start = [33793,18433,16513,1]
# start = [33793,18433,16641,1]
# start = [33793,18433,16769,1]
# start = [33793,18433,16897,1]
# start = [33793,19457,16385,1]
# start = [33793,19457,16513,1]
# start = [33793,19457,16769,1]
# start = [33793,19457,16897,1]
# start = [33793,20481,16385,1]
# start = [33793,20481,16513,1]
# start = [33793,20481,16641,1]
# start = [33793,20481,16769,1]
# start = [33793,21505,16385,1]
# start = [33793,21505,16513,1]
# start = [33793,21505,16641,1]
# start = [33793,21505,16769,1]
# start = [33793,21505,16897,1]
# start = [33793,22529,16385,1]
# start = [33793,22529,16513,1]
# start = [33793,22529,16641,1]
# start = [33793,22529,16769,1]
# start = [33793,23553,16385,1]
# start = [33793,23553,16513,1]
# start = [33793,23553,16769,1]
# start = [33793,24577,16385,1]
# start = [33793,24577,16513,1]
# start = [33793,24577,16769,1]
# start = [33793,25601,16385,1]
# start = [33793,25601,16513,1]
# start = [33793,25601,16769,1]
# start = [33793,26625,16385,1]
# start = [33793,26625,16513,1]
# start = [33793,26625,16641,1]
# start = [33793,26625,16769,1]
# start = [33793,27649,16385,1]
# start = [33793,27649,16513,1]
# start = [33793,27649,16769,1]
# start = [33793,28673,16385,1]
# start = [33793,28673,16513,1]
# start = [33793,28673,16641,1]
# start = [33793,28673,16769,1]
# start = [33793,29697,16385,1]
# start = [33793,29697,16513,1]
# start = [33793,29697,16641,1]
# start = [33793,29697,16769,1]
# start = [33793,30721,16385,1]
# start = [33793,30721,16513,1]
# start = [33793,30721,16769,1]
# start = [33793,31745,16385,1]
# start = [33793,31745,16513,1]
# start = [33793,31745,16641,1]
# start = [33793,31745,16769,1]
# start = [33793,32769,16385,1]
# start = [33793,32769,16513,1]
# start = [33793,32769,16769,1]
# start = [33793,33793,16385,1]
# start = [33793,33793,16513,1]
# start = [33793,33793,16641,1]
# start = [33793,33793,16769,1]
# start = [34817,17409,16385,1]
# start = [34817,17409,16769,1]
# start = [34817,17409,16897,1]
# start = [34817,18433,16385,1]
# start = [34817,18433,16513,1]
# start = [34817,18433,16641,1]
# start = [34817,18433,16769,1]
# start = [34817,19457,16385,1]
# start = [34817,19457,16513,1]
# start = [34817,19457,16769,1]
# start = [34817,19457,16897,1]
# start = [34817,20481,16385,1]
# start = [34817,20481,16513,1]
# start = [34817,20481,16641,1]
# start = [34817,20481,16769,1]
# start = [34817,20481,16897,1]
# start = [34817,21505,16385,1]
# start = [34817,21505,16513,1]
# start = [34817,21505,16641,1]
# start = [34817,21505,16769,1]
# start = [34817,22529,16385,1]
# start = [34817,22529,16513,1]
# start = [34817,22529,16641,1]
# start = [34817,22529,16769,1]
# start = [34817,22529,16897,1]
# start = [34817,23553,16385,1]
# start = [34817,23553,16513,1]
# start = [34817,23553,16641,1]
# start = [34817,23553,16769,1]
# start = [34817,23553,16897,1]
# start = [34817,24577,16385,1]
# start = [34817,24577,16513,1]
# start = [34817,24577,16641,1]
# start = [34817,24577,16769,1]
# start = [34817,25601,16385,1]
# start = [34817,25601,16513,1]
# start = [34817,25601,16769,1]
# start = [34817,26625,16385,1]
# start = [34817,26625,16513,1]
# start = [34817,26625,16769,1]
# start = [34817,27649,16385,1]
# start = [34817,27649,16513,1]
# start = [34817,27649,16641,1]
# start = [34817,27649,16769,1]
# start = [34817,28673,16385,1]
# start = [34817,28673,16513,1]
# start = [34817,28673,16641,1]
# start = [34817,28673,16769,1]
# start = [34817,29697,16385,1]
# start = [34817,29697,16513,1]
# start = [34817,29697,16769,1]
# start = [34817,30721,16385,1]
# start = [34817,30721,16513,1]
# start = [34817,30721,16641,1]
# start = [34817,30721,16769,1]
# start = [34817,31745,16385,1]
# start = [34817,31745,16513,1]
# start = [34817,31745,16769,1]
# start = [34817,32769,16385,1]
# start = [34817,32769,16513,1]
# start = [34817,32769,16641,1]
# start = [34817,32769,16769,1]
# start = [34817,33793,16513,1]
# start = [34817,33793,16769,1]
# start = [35841,17409,16385,1]
# start = [35841,17409,16769,1]
# start = [35841,18433,16385,1]
# start = [35841,18433,16513,1]
# start = [35841,18433,16641,1]
# start = [35841,18433,16769,1]
# start = [35841,18433,16897,1]
# start = [35841,19457,16385,1]
# start = [35841,19457,16513,1]
# start = [35841,19457,16641,1]
# start = [35841,19457,16769,1]
# start = [35841,20481,16385,1]
# start = [35841,20481,16513,1]
# start = [35841,20481,16641,1]
# start = [35841,20481,16769,1]
# start = [35841,20481,16897,1]
# start = [35841,21505,16385,1]
# start = [35841,21505,16513,1]
# start = [35841,21505,16641,1]
# start = [35841,21505,16769,1]
# start = [35841,22529,16385,1]
# start = [35841,22529,16513,1]
# start = [35841,22529,16769,1]
# start = [35841,22529,16897,1]
# start = [35841,23553,16385,1]
# start = [35841,23553,16513,1]
# start = [35841,23553,16641,1]
# start = [35841,23553,16769,1]
# start = [35841,24577,16385,1]
# start = [35841,24577,16513,1]
# start = [35841,24577,16641,1]
# start = [35841,24577,16769,1]
# start = [35841,25601,16385,1]
# start = [35841,25601,16513,1]
# start = [35841,25601,16769,1]
# start = [35841,26625,16385,1]
# start = [35841,26625,16513,1]
# start = [35841,26625,16769,1]
# start = [35841,27649,16385,1]
# start = [35841,27649,16769,1]
# start = [35841,28673,16385,1]
# start = [35841,28673,16513,1]
# start = [35841,28673,16641,1]
# start = [35841,28673,16769,1]
# start = [35841,29697,16385,1]
# start = [35841,29697,16513,1]
# start = [35841,29697,16769,1]
# start = [35841,30721,16385,1]
# start = [35841,30721,16513,1]
# start = [35841,30721,16641,1]
# start = [35841,30721,16769,1]
# start = [35841,31745,16385,1]
# start = [35841,31745,16513,1]
# start = [35841,31745,16641,1]
# start = [35841,31745,16769,1]
# start = [35841,32769,16385,1]
# start = [35841,32769,16513,1]
# start = [35841,32769,16641,1]
# start = [35841,32769,16769,1]
# start = [35841,33793,16513,1]
# start = [35841,33793,16641,1]
# start = [35841,33793,16769,1]
# start = [35841,34817,16641,1]
# start = [35841,36865,16641,1]
# start = [35841,37889,16641,1]
# start = [35841,38913,16641,1]
# start = [35841,39937,16641,1]
# start = [36865,17409,16385,1]
# start = [36865,17409,16641,1]
# start = [36865,17409,16769,1]
# start = [36865,17409,16897,1]
# start = [36865,18433,16385,1]
# start = [36865,18433,16513,1]
# start = [36865,18433,16641,1]
# start = [36865,18433,16769,1]
# start = [36865,18433,16897,1]
# start = [36865,19457,16385,1]
# start = [36865,19457,16513,1]
# start = [36865,19457,16769,1]
# start = [36865,19457,16897,1]
# start = [36865,20481,16385,1]
# start = [36865,20481,16513,1]
# start = [36865,20481,16641,1]
# start = [36865,20481,16769,1]
# start = [36865,21505,16385,1]
# start = [36865,21505,16513,1]
# start = [36865,21505,16769,1]
# start = [36865,21505,16897,1]
# start = [36865,22529,16385,1]
# start = [36865,22529,16513,1]
# start = [36865,22529,16769,1]
# start = [36865,23553,16385,1]
# start = [36865,23553,16513,1]
# start = [36865,23553,16641,1]
# start = [36865,23553,16769,1]
# start = [36865,24577,16385,1]
# start = [36865,24577,16513,1]
# start = [36865,24577,16769,1]
# start = [36865,25601,16385,1]
# start = [36865,25601,16513,1]
# start = [36865,25601,16769,1]
# start = [36865,25601,16897,1]
# start = [36865,26625,16385,1]
# start = [36865,26625,16513,1]
# start = [36865,26625,16641,1]
# start = [36865,26625,16769,1]
# start = [36865,26625,16897,1]
# start = [36865,27649,16385,1]
# start = [36865,27649,16513,1]
# start = [36865,27649,16769,1]
# start = [36865,28673,16385,1]
# start = [36865,28673,16513,1]
# start = [36865,28673,16641,1]
# start = [36865,28673,16769,1]
# start = [36865,29697,16385,1]
# start = [36865,29697,16513,1]
# start = [36865,29697,16641,1]
# start = [36865,29697,16769,1]
# start = [36865,30721,16385,1]
# start = [36865,30721,16641,1]
# start = [36865,30721,16769,1]
# start = [36865,31745,16385,1]
# start = [36865,31745,16513,1]
# start = [36865,31745,16641,1]
# start = [36865,31745,16769,1]
# start = [36865,32769,16385,1]
# start = [36865,32769,16513,1]
# start = [36865,32769,16641,1]
# start = [36865,32769,16769,1]
# start = [36865,33793,16385,1]
# start = [36865,33793,16513,1]
# start = [36865,33793,16769,1]
# start = [36865,34817,16385,1]
# start = [36865,34817,16513,1]
# start = [36865,34817,16769,1]
# start = [36865,35841,16385,1]
# start = [36865,35841,16641,1]
# start = [36865,35841,16769,1]
# start = [36865,36865,16385,1]
# start = [36865,36865,16513,1]
# start = [36865,36865,16641,1]
# start = [36865,36865,16769,1]
# start = [36865,37889,16385,1]
# start = [36865,37889,16513,1]
# start = [36865,37889,16641,1]
# start = [36865,37889,16769,1]
# start = [36865,38913,16385,1]
# start = [36865,38913,16513,1]
# start = [36865,38913,16641,1]
# start = [36865,38913,16769,1]
# start = [36865,39937,16385,1]
# start = [36865,39937,16641,1]
# start = [36865,39937,16769,1]
# start = [36865,40961,16641,1]
# start = [36865,40961,16769,1]
# start = [37889,17409,16385,1]
# start = [37889,17409,16513,1]
# start = [37889,17409,16769,1]
# start = [37889,17409,16897,1]
# start = [37889,18433,16385,1]
# start = [37889,18433,16513,1]
# start = [37889,18433,16769,1]
# start = [37889,19457,16385,1]
# start = [37889,19457,16513,1]
# start = [37889,19457,16641,1]
# start = [37889,19457,16769,1]
# start = [37889,19457,16897,1]
# start = [37889,20481,16385,1]
# start = [37889,20481,16513,1]
# start = [37889,20481,16769,1]
# start = [37889,20481,16897,1]
# start = [37889,21505,16385,1]
# start = [37889,21505,16513,1]
# start = [37889,21505,16769,1]
# start = [37889,21505,16897,1]
# start = [37889,22529,16385,1]
# start = [37889,22529,16513,1]
# start = [37889,22529,16769,1]
# start = [37889,23553,16385,1]
# start = [37889,23553,16513,1]
# start = [37889,23553,16641,1]
# start = [37889,23553,16769,1]
# start = [37889,23553,16897,1]
# start = [37889,24577,16385,1]
# start = [37889,24577,16513,1]
# start = [37889,24577,16641,1]
# start = [37889,24577,16769,1]
# start = [37889,24577,16897,1]
# start = [37889,25601,16385,1]
# start = [37889,25601,16769,1]
# start = [37889,26625,16385,1]
# start = [37889,26625,16513,1]
# start = [37889,26625,16641,1]
# start = [37889,26625,16769,1]
# start = [37889,27649,16385,1]
# start = [37889,27649,16513,1]
# start = [37889,27649,16769,1]
# start = [37889,27649,16897,1]
# start = [37889,28673,16385,1]
# start = [37889,28673,16513,1]
# start = [37889,28673,16769,1]
# start = [37889,29697,16385,1]
# start = [37889,29697,16513,1]
# start = [37889,29697,16641,1]
# start = [37889,29697,16769,1]
# start = [37889,29697,16897,1]
# start = [37889,30721,16385,1]
# start = [37889,30721,16769,1]
# start = [37889,31745,16385,1]
# start = [37889,31745,16513,1]
# start = [37889,31745,16641,1]
# start = [37889,31745,16769,1]
# start = [37889,32769,16385,1]
# start = [37889,32769,16641,1]
# start = [37889,32769,16769,1]
# start = [37889,33793,16385,1]
# start = [37889,33793,16769,1]
# start = [37889,34817,16385,1]
# start = [37889,34817,16641,1]
# start = [37889,34817,16769,1]
# start = [37889,35841,16385,1]
# start = [37889,35841,16641,1]
# start = [37889,35841,16769,1]
# start = [37889,36865,16385,1]
# start = [37889,36865,16769,1]
# start = [37889,37889,16385,1]
# start = [37889,37889,16513,1]
# start = [37889,37889,16641,1]
# start = [37889,37889,16769,1]
# start = [37889,38913,16385,1]
# start = [37889,38913,16641,1]
# start = [37889,38913,16769,1]
# start = [37889,39937,16385,1]
# start = [37889,39937,16641,1]
# start = [37889,39937,16769,1]
# start = [37889,40961,16513,1]
# start = [37889,40961,16641,1]
# start = [37889,40961,16769,1]
# start = [38913,17409,16385,1]
# start = [38913,17409,16513,1]
# start = [38913,17409,16769,1]
# start = [38913,17409,16897,1]
# start = [38913,18433,16385,1]
# start = [38913,18433,16513,1]
# start = [38913,18433,16769,1]
# start = [38913,19457,16385,1]
# start = [38913,19457,16513,1]
# start = [38913,19457,16769,1]
# start = [38913,19457,16897,1]
# start = [38913,20481,16385,1]
# start = [38913,20481,16513,1]
# start = [38913,20481,16641,1]
# start = [38913,20481,16769,1]
# start = [38913,20481,16897,1]
# start = [38913,21505,16385,1]
# start = [38913,21505,16513,1]
# start = [38913,21505,16769,1]
# start = [38913,22529,16385,1]
# start = [38913,22529,16513,1]
# start = [38913,22529,16641,1]
# start = [38913,22529,16769,1]
# start = [38913,22529,16897,1]
# start = [38913,23553,16385,1]
# start = [38913,23553,16513,1]
# start = [38913,23553,16641,1]
# start = [38913,23553,16769,1]
# start = [38913,24577,16385,1]
# start = [38913,24577,16513,1]
# start = [38913,24577,16641,1]
# start = [38913,24577,16769,1]
# start = [38913,25601,16385,1]
# start = [38913,25601,16513,1]
# start = [38913,25601,16641,1]
# start = [38913,25601,16769,1]
# start = [38913,26625,16385,1]
# start = [38913,26625,16641,1]
# start = [38913,26625,16769,1]
# start = [38913,27649,16385,1]
# start = [38913,27649,16513,1]
# start = [38913,27649,16641,1]
# start = [38913,27649,16769,1]
# start = [38913,28673,16385,1]
# start = [38913,28673,16513,1]
# start = [38913,28673,16769,1]
# start = [38913,29697,16385,1]
# start = [38913,29697,16513,1]
# start = [38913,29697,16641,1]
# start = [38913,29697,16769,1]
# start = [38913,30721,16385,1]
# start = [38913,30721,16513,1]
# start = [38913,30721,16769,1]
# start = [38913,31745,16385,1]
# start = [38913,31745,16641,1]
# start = [38913,31745,16769,1]
# start = [38913,32769,16385,1]
# start = [38913,32769,16513,1]
# start = [38913,32769,16641,1]
# start = [38913,32769,16769,1]
# start = [38913,33793,16385,1]
# start = [38913,33793,16513,1]
# start = [38913,33793,16769,1]
# start = [38913,34817,16385,1]
# start = [38913,34817,16513,1]
# start = [38913,34817,16641,1]
# start = [38913,34817,16769,1]
# start = [38913,35841,16385,1]
# start = [38913,35841,16513,1]
# start = [38913,35841,16769,1]
# start = [38913,36865,16385,1]
# start = [38913,36865,16769,1]
# start = [38913,37889,16385,1]
# start = [38913,37889,16513,1]
# start = [38913,37889,16769,1]
# start = [38913,38913,16385,1]
# start = [38913,38913,16769,1]
# start = [38913,39937,16385,1]
# start = [38913,39937,16513,1]
# start = [38913,39937,16641,1]
# start = [38913,39937,16769,1]
# start = [38913,40961,16513,1]
# start = [38913,40961,16641,1]
# start = [39937,17409,16385,1]
# start = [39937,17409,16513,1]
# start = [39937,17409,16641,1]
# start = [39937,17409,16769,1]
# start = [39937,17409,16897,1]
# start = [39937,18433,16385,1]
# start = [39937,18433,16513,1]
# start = [39937,18433,16641,1]
# start = [39937,18433,16769,1]
# start = [39937,18433,16897,1]
# start = [39937,19457,16385,1]
# start = [39937,19457,16513,1]
# start = [39937,19457,16769,1]
# start = [39937,19457,16897,1]
# start = [39937,20481,16385,1]
# start = [39937,20481,16513,1]
# start = [39937,20481,16641,1]
# start = [39937,20481,16769,1]
# start = [39937,20481,16897,1]
# start = [39937,21505,16385,1]
# start = [39937,21505,16513,1]
# start = [39937,21505,16641,1]
# start = [39937,21505,16769,1]
# start = [39937,21505,16897,1]
# start = [39937,22529,16385,1]
# start = [39937,22529,16513,1]
# start = [39937,22529,16641,1]
# start = [39937,22529,16769,1]
# start = [39937,22529,16897,1]
# start = [39937,23553,16385,1]
# start = [39937,23553,16513,1]
# start = [39937,23553,16641,1]
# start = [39937,23553,16769,1]
# start = [39937,23553,16897,1]
# start = [39937,24577,16385,1]
# start = [39937,24577,16513,1]
# start = [39937,24577,16641,1]
# start = [39937,24577,16769,1]
# start = [39937,24577,16897,1]
# start = [39937,25601,16385,1]
# start = [39937,25601,16641,1]
# start = [39937,25601,16769,1]
# start = [39937,25601,16897,1]
# start = [39937,26625,16385,1]
# start = [39937,26625,16513,1]
# start = [39937,26625,16641,1]
# start = [39937,26625,16769,1]
# start = [39937,27649,16385,1]
# start = [39937,27649,16513,1]
# start = [39937,27649,16769,1]
# start = [39937,28673,16385,1]
# start = [39937,28673,16513,1]
# start = [39937,28673,16641,1]
# start = [39937,28673,16769,1]
# start = [39937,29697,16385,1]
# start = [39937,29697,16641,1]
# start = [39937,29697,16769,1]
# start = [39937,30721,16385,1]
# start = [39937,30721,16513,1]
# start = [39937,30721,16641,1]
# start = [39937,30721,16769,1]
# start = [39937,31745,16385,1]
# start = [39937,31745,16513,1]
# start = [39937,31745,16641,1]
# start = [39937,31745,16769,1]
# start = [39937,32769,16385,1]
# start = [39937,32769,16513,1]
# start = [39937,32769,16641,1]
# start = [39937,32769,16769,1]
# start = [39937,33793,16385,1]
# start = [39937,33793,16769,1]
# start = [39937,34817,16385,1]
# start = [39937,34817,16513,1]
# start = [39937,34817,16641,1]
# start = [39937,34817,16769,1]
# start = [39937,35841,16385,1]
# start = [39937,35841,16513,1]
# start = [39937,35841,16641,1]
# start = [39937,35841,16769,1]
# start = [39937,36865,16385,1]
# start = [39937,36865,16513,1]
# start = [39937,36865,16769,1]
# start = [39937,37889,16385,1]
# start = [39937,37889,16513,1]
# start = [39937,37889,16641,1]
# start = [39937,37889,16769,1]
# start = [39937,38913,16385,1]
# start = [39937,38913,16513,1]
# start = [39937,38913,16641,1]
# start = [39937,38913,16769,1]
# start = [39937,39937,16385,1]
# start = [39937,39937,16513,1]
# start = [39937,39937,16641,1]
# start = [39937,39937,16769,1]
# start = [39937,40961,16513,1]
# start = [39937,40961,16641,1]
# start = [40961,16385,16897,1]
# start = [40961,17409,16385,1]
# start = [40961,17409,16513,1]
# start = [40961,17409,16769,1]
# start = [40961,18433,16385,1]
# start = [40961,18433,16513,1]
# start = [40961,18433,16641,1]
# start = [40961,18433,16769,1]
# start = [40961,18433,16897,1]
# start = [40961,19457,16385,1]
# start = [40961,19457,16513,1]
# start = [40961,19457,16769,1]
# start = [40961,20481,16385,1]
# start = [40961,20481,16513,1]
# start = [40961,20481,16641,1]
# start = [40961,20481,16769,1]
# start = [40961,21505,16385,1]
# start = [40961,21505,16513,1]
# start = [40961,21505,16641,1]
# start = [40961,21505,16769,1]
# start = [40961,22529,16385,1]
# start = [40961,22529,16513,1]
# start = [40961,22529,16769,1]
# start = [40961,23553,16385,1]
# start = [40961,23553,16513,1]
# start = [40961,23553,16641,1]
# start = [40961,23553,16769,1]
# start = [40961,24577,16385,1]
# start = [40961,24577,16513,1]
# start = [40961,24577,16641,1]
# start = [40961,24577,16769,1]
# start = [40961,25601,16385,1]
# start = [40961,25601,16513,1]
# start = [40961,25601,16769,1]
# start = [40961,25601,16897,1]
# start = [40961,26625,16385,1]
# start = [40961,26625,16513,1]
# start = [40961,26625,16641,1]
# start = [40961,26625,16769,1]
# start = [40961,27649,16385,1]
# start = [40961,27649,16513,1]
# start = [40961,27649,16641,1]
# start = [40961,27649,16769,1]
# start = [40961,27649,16897,1]
# start = [40961,28673,16385,1]
# start = [40961,28673,16513,1]
# start = [40961,28673,16769,1]
# start = [40961,28673,16897,1]
# start = [40961,29697,16385,1]
# start = [40961,29697,16513,1]
# start = [40961,29697,16641,1]
# start = [40961,29697,16769,1]
# start = [40961,30721,16385,1]
# start = [40961,30721,16513,1]
# start = [40961,30721,16769,1]
# start = [40961,31745,16385,1]
# start = [40961,31745,16513,1]
# start = [40961,31745,16641,1]
# start = [40961,31745,16769,1]
# start = [40961,32769,16385,1]
# start = [40961,32769,16513,1]
# start = [40961,32769,16641,1]
# start = [40961,32769,16769,1]
# start = [40961,33793,16385,1]
# start = [40961,33793,16513,1]
# start = [40961,33793,16641,1]
# start = [40961,33793,16769,1]
# start = [40961,34817,16385,1]
# start = [40961,34817,16513,1]
# start = [40961,34817,16641,1]
# start = [40961,34817,16769,1]
# start = [40961,35841,16385,1]
# start = [40961,35841,16513,1]
# start = [40961,35841,16641,1]
# start = [40961,35841,16769,1]
# start = [40961,36865,16385,1]
# start = [40961,36865,16513,1]
# start = [40961,36865,16641,1]
# start = [40961,36865,16769,1]
# start = [40961,37889,16385,1]
# start = [40961,37889,16641,1]
# start = [40961,37889,16769,1]
# start = [40961,38913,16385,1]
# start = [40961,38913,16513,1]
# start = [40961,38913,16641,1]
# start = [40961,38913,16769,1]
# start = [40961,39937,16385,1]
# start = [40961,39937,16513,1]
# start = [40961,39937,16641,1]
# start = [40961,39937,16769,1]
# start = [40961,40961,16513,1]
# start = [40961,40961,16641,1]
# start = [41985,16385,16897,1]
# start = [41985,17409,16385,1]
# start = [41985,17409,16513,1]
# start = [41985,17409,16641,1]
# start = [41985,17409,16769,1]
# start = [41985,17409,16897,1]
# start = [41985,18433,16385,1]
# start = [41985,18433,16641,1]
# start = [41985,18433,16769,1]
# start = [41985,19457,16385,1]
# start = [41985,19457,16513,1]
# start = [41985,19457,16769,1]
# start = [41985,19457,16897,1]
# start = [41985,20481,16385,1]
# start = [41985,20481,16513,1]
# start = [41985,20481,16641,1]
# start = [41985,20481,16769,1]
# start = [41985,20481,16897,1]
# start = [41985,21505,16385,1]
# start = [41985,21505,16513,1]
# start = [41985,21505,16641,1]
# start = [41985,21505,16769,1]
# start = [41985,21505,16897,1]
# start = [41985,22529,16385,1]
# start = [41985,22529,16513,1]
# start = [41985,22529,16769,1]
# start = [41985,23553,16385,1]
# start = [41985,23553,16513,1]
# start = [41985,23553,16769,1]
# start = [41985,24577,16385,1]
# start = [41985,24577,16513,1]
# start = [41985,24577,16641,1]
# start = [41985,24577,16769,1]
# start = [41985,25601,16385,1]
# start = [41985,25601,16513,1]
# start = [41985,25601,16641,1]
# start = [41985,25601,16769,1]
# start = [41985,26625,16385,1]
# start = [41985,26625,16513,1]
# start = [41985,26625,16641,1]
# start = [41985,26625,16769,1]
# start = [41985,26625,16897,1]
# start = [41985,27649,16385,1]
# start = [41985,27649,16513,1]
# start = [41985,27649,16769,1]
# start = [41985,27649,16897,1]
# start = [41985,28673,16385,1]
# start = [41985,28673,16513,1]
# start = [41985,28673,16641,1]
# start = [41985,28673,16769,1]
# start = [41985,29697,16385,1]
# start = [41985,29697,16641,1]
# start = [41985,29697,16769,1]
# start = [41985,30721,16385,1]
# start = [41985,30721,16513,1]
# start = [41985,30721,16769,1]
# start = [41985,31745,16385,1]
# start = [41985,31745,16641,1]
# start = [41985,31745,16769,1]
# start = [41985,32769,16385,1]
# start = [41985,32769,16513,1]
# start = [41985,32769,16769,1]
# start = [41985,33793,16385,1]
# start = [41985,33793,16513,1]
# start = [41985,33793,16769,1]
# start = [41985,34817,16385,1]
# start = [41985,34817,16513,1]
# start = [41985,34817,16641,1]
# start = [41985,34817,16769,1]
# start = [41985,35841,16385,1]
# start = [41985,35841,16513,1]
# start = [41985,35841,16641,1]
# start = [41985,35841,16769,1]
# start = [41985,36865,16385,1]
# start = [41985,36865,16513,1]
# start = [41985,36865,16769,1]
# start = [41985,37889,16385,1]
# start = [41985,37889,16513,1]
# start = [41985,37889,16641,1]
# start = [41985,37889,16769,1]
# start = [41985,38913,16385,1]
# start = [41985,38913,16513,1]
# start = [41985,38913,16641,1]
# start = [41985,38913,16769,1]
# start = [41985,39937,16385,1]
# start = [41985,39937,16513,1]
# start = [41985,39937,16641,1]
# start = [41985,39937,16769,1]
# start = [41985,40961,16513,1]
# start = [41985,40961,16641,1]
# start = [43009,16385,16897,1]
# start = [43009,17409,16385,1]
# start = [43009,17409,16513,1]
# start = [43009,17409,16769,1]
# start = [43009,17409,16897,1]
# start = [43009,18433,16385,1]
# start = [43009,18433,16513,1]
# start = [43009,18433,16641,1]
# start = [43009,18433,16769,1]
# start = [43009,19457,16385,1]
# start = [43009,19457,16513,1]
# start = [43009,19457,16769,1]
# start = [43009,19457,16897,1]
# start = [43009,20481,16385,1]
# start = [43009,20481,16513,1]
# start = [43009,20481,16769,1]
# start = [43009,20481,16897,1]
# start = [43009,21505,16385,1]
# start = [43009,21505,16513,1]
# start = [43009,21505,16641,1]
# start = [43009,21505,16769,1]
# start = [43009,22529,16385,1]
# start = [43009,22529,16513,1]
# start = [43009,22529,16769,1]
# start = [43009,22529,16897,1]
# ...
# start = [71681,33793,16769,1]
# start = [71681,34817,16385,1]
# start = [71681,34817,16513,1]
# start = [71681,34817,16641,1]
# start = [71681,34817,16769,1]
# start = [71681,35841,16385,1]
# start = [71681,35841,16513,1]
# start = [71681,35841,16641,1]
# start = [71681,35841,16769,1]
# start = [71681,36865,16385,1]
# start = [71681,36865,16513,1]
# start = [71681,36865,16641,1]
# start = [71681,36865,16769,1]
# start = [71681,37889,16385,1]
# start = [71681,37889,16513,1]
# start = [71681,37889,16641,1]
# start = [71681,37889,16769,1]
# start = [71681,38913,16385,1]
# start = [71681,38913,16513,1]
# start = [71681,38913,16641,1]
# start = [71681,38913,16769,1]
# start = [71681,39937,16385,1]
# start = [71681,39937,16513,1]
# start = [71681,39937,16641,1]
# start = [71681,39937,16769,1]
# start = [71681,40961,16385,1]
# start = [71681,40961,16641,1]
# start = [71681,40961,16769,1]
# start = [71681,41985,16385,1]
# start = [71681,41985,16641,1]
# start = [71681,41985,16769,1]
# start = [71681,43009,16385,1]
# start = [71681,43009,16513,1]
# start = [71681,43009,16641,1]
# start = [71681,43009,16769,1]
# start = [71681,44033,16385,1]
# start = [71681,44033,16513,1]
# start = [71681,44033,16641,1]
# start = [71681,44033,16769,1]
# start = [71681,45057,16513,1]
# start = [71681,45057,16641,1]
# start = [71681,45057,16769,1]
# start = [72705,12289,16897,1]
# start = [72705,13313,16769,1]
# start = [72705,13313,16897,1]
# start = [72705,14337,16513,1]
# start = [72705,14337,16641,1]
# start = [72705,14337,16769,1]
# start = [72705,14337,16897,1]
# start = [72705,15361,16385,1]
# start = [72705,15361,16513,1]
# start = [72705,15361,16641,1]
# start = [72705,15361,16769,1]
# start = [72705,15361,16897,1]
# start = [72705,16385,16385,1]
# start = [72705,16385,16513,1]
# start = [72705,16385,16641,1]
# start = [72705,16385,16769,1]
# start = [72705,16385,16897,1]
# start = [72705,17409,16385,1]
# start = [72705,17409,16513,1]
# start = [72705,17409,16641,1]
# start = [72705,17409,16769,1]
# start = [72705,18433,16385,1]
# start = [72705,18433,16513,1]
# start = [72705,18433,16769,1]
# start = [72705,19457,16385,1]
# start = [72705,19457,16513,1]
# start = [72705,19457,16641,1]
# start = [72705,19457,16769,1]
# start = [72705,19457,16897,1]
# start = [72705,20481,16385,1]
# start = [72705,20481,16513,1]
# start = [72705,20481,16641,1]
# start = [72705,20481,16769,1]
# start = [72705,20481,16897,1]
# start = [72705,21505,16385,1]
# start = [72705,21505,16513,1]
# start = [72705,21505,16641,1]
# start = [72705,21505,16769,1]
# start = [72705,22529,16385,1]
# start = [72705,22529,16513,1]
# start = [72705,22529,16769,1]
# start = [72705,22529,16897,1]
# start = [72705,23553,16385,1]
# start = [72705,23553,16513,1]
# start = [72705,23553,16641,1]
# start = [72705,23553,16769,1]
# start = [72705,24577,16385,1]
# start = [72705,24577,16641,1]
# start = [72705,24577,16769,1]
# start = [72705,25601,16385,1]
# start = [72705,25601,16513,1]
# start = [72705,25601,16641,1]
# start = [72705,25601,16769,1]
# start = [72705,26625,16385,1]
# start = [72705,26625,16513,1]
# start = [72705,26625,16641,1]
# start = [72705,26625,16769,1]
# start = [72705,27649,16385,1]
# start = [72705,27649,16641,1]
# start = [72705,27649,16769,1]
# start = [72705,28673,16385,1]
# start = [72705,28673,16513,1]
# start = [72705,28673,16641,1]
# start = [72705,28673,16769,1]
# start = [72705,29697,16385,1]
# start = [72705,29697,16513,1]
# start = [72705,29697,16641,1]
# start = [72705,29697,16769,1]
# start = [72705,30721,16385,1]
# start = [72705,30721,16513,1]
# start = [72705,30721,16641,1]
# start = [72705,30721,16769,1]
# start = [72705,31745,16385,1]
# start = [72705,31745,16513,1]
# start = [72705,31745,16641,1]
# start = [72705,31745,16769,1]
# start = [72705,32769,16385,1]
# start = [72705,32769,16641,1]
# start = [72705,32769,16769,1]
# start = [72705,33793,16385,1]
# start = [72705,33793,16513,1]
# start = [72705,33793,16769,1]
# start = [72705,34817,16385,1]
# start = [72705,34817,16769,1]
# start = [72705,35841,16385,1]
# start = [72705,35841,16513,1]
# start = [72705,35841,16641,1]
# start = [72705,35841,16769,1]
# start = [72705,36865,16385,1]
# start = [72705,36865,16769,1]
# start = [72705,37889,16385,1]
# start = [72705,37889,16513,1]
# start = [72705,37889,16641,1]
# start = [72705,37889,16769,1]
# start = [72705,38913,16385,1]
# start = [72705,38913,16513,1]
# start = [72705,38913,16641,1]
# start = [72705,38913,16769,1]
# start = [72705,39937,16385,1]
# start = [72705,39937,16513,1]
# start = [72705,39937,16641,1]
# start = [72705,39937,16769,1]
# start = [72705,40961,16385,1]
# start = [72705,40961,16513,1]
# start = [72705,40961,16641,1]
# start = [72705,40961,16769,1]
# start = [72705,41985,16385,1]
# start = [72705,41985,16513,1]
# start = [72705,41985,16641,1]
# start = [72705,41985,16769,1]
# start = [72705,43009,16385,1]
# start = [72705,43009,16513,1]
# start = [72705,43009,16641,1]
# start = [72705,43009,16769,1]
# start = [72705,44033,16385,1]
# start = [72705,44033,16513,1]
# start = [72705,44033,16641,1]
# start = [72705,44033,16769,1]
# start = [72705,45057,16513,1]
# start = [72705,45057,16641,1]
# start = [72705,45057,16769,1]
# start = [72705,46081,16513,1]
# start = [73729,12289,16897,1]
# start = [73729,13313,16769,1]
# start = [73729,13313,16897,1]
# start = [73729,14337,16513,1]
# start = [73729,14337,16641,1]
# start = [73729,14337,16769,1]
# start = [73729,15361,16513,1]
# start = [73729,15361,16641,1]
# start = [73729,15361,16769,1]
# start = [73729,16385,16385,1]
# start = [73729,16385,16513,1]
# start = [73729,16385,16641,1]
# start = [73729,16385,16769,1]
# start = [73729,16385,16897,1]
# start = [73729,17409,16385,1]
# start = [73729,17409,16513,1]
# start = [73729,17409,16641,1]
# start = [73729,17409,16769,1]
# start = [73729,17409,16897,1]
# start = [73729,18433,16385,1]
# start = [73729,18433,16513,1]
# start = [73729,18433,16769,1]
# start = [73729,19457,16385,1]
# start = [73729,19457,16513,1]
# start = [73729,19457,16641,1]
# start = [73729,19457,16769,1]
# start = [73729,19457,16897,1]
# start = [73729,20481,16385,1]
# start = [73729,20481,16513,1]
# start = [73729,20481,16641,1]
# start = [73729,20481,16769,1]
# start = [73729,20481,16897,1]
# start = [73729,21505,16385,1]
# start = [73729,21505,16513,1]
# start = [73729,21505,16641,1]
# start = [73729,21505,16769,1]
# start = [73729,21505,16897,1]
# start = [73729,22529,16385,1]
# start = [73729,22529,16513,1]
# start = [73729,22529,16641,1]
# start = [73729,22529,16769,1]
# start = [73729,22529,16897,1]
# start = [73729,23553,16385,1]
# start = [73729,23553,16513,1]
# start = [73729,23553,16769,1]
# start = [73729,23553,16897,1]
# start = [73729,24577,16385,1]
# start = [73729,24577,16513,1]
# start = [73729,24577,16769,1]
# start = [73729,24577,16897,1]
# start = [73729,25601,16385,1]
# start = [73729,25601,16513,1]
# start = [73729,25601,16769,1]
# start = [73729,26625,16385,1]
# start = [73729,26625,16513,1]
# start = [73729,26625,16641,1]
# start = [73729,26625,16769,1]
# start = [73729,26625,16897,1]
# start = [73729,27649,16385,1]
# start = [73729,27649,16513,1]
# start = [73729,27649,16769,1]
# start = [73729,28673,16385,1]
# start = [73729,28673,16513,1]
# start = [73729,28673,16641,1]
# start = [73729,28673,16769,1]
# start = [73729,29697,16385,1]
# start = [73729,29697,16513,1]
# start = [73729,29697,16769,1]
# start = [73729,30721,16385,1]
# start = [73729,30721,16641,1]
# start = [73729,30721,16769,1]
# start = [73729,31745,16385,1]
# start = [73729,31745,16513,1]
# start = [73729,31745,16641,1]
# start = [73729,31745,16769,1]
# start = [73729,32769,16385,1]
# start = [73729,32769,16513,1]
# start = [73729,32769,16641,1]
# start = [73729,32769,16769,1]
# start = [73729,33793,16385,1]
# start = [73729,33793,16513,1]
# start = [73729,33793,16769,1]
# start = [73729,34817,16385,1]
# start = [73729,34817,16513,1]
# start = [73729,34817,16641,1]
# start = [73729,34817,16769,1]
# start = [73729,35841,16385,1]
# start = [73729,35841,16513,1]
# start = [73729,35841,16769,1]
# start = [73729,36865,16385,1]
# start = [73729,36865,16513,1]
# start = [73729,36865,16641,1]
# start = [73729,36865,16769,1]
# start = [73729,37889,16385,1]
# start = [73729,37889,16513,1]
# start = [73729,37889,16641,1]
# start = [73729,37889,16769,1]
# start = [73729,38913,16385,1]
# start = [73729,38913,16641,1]
# start = [73729,38913,16769,1]
# start = [73729,39937,16385,1]
# start = [73729,39937,16641,1]
# start = [73729,39937,16769,1]
# start = [73729,40961,16385,1]
# start = [73729,40961,16513,1]
# start = [73729,40961,16641,1]
# start = [73729,40961,16769,1]
# start = [73729,41985,16385,1]
# start = [73729,41985,16513,1]
# start = [73729,41985,16641,1]
# start = [73729,41985,16769,1]
# start = [73729,43009,16385,1]
# start = [73729,43009,16641,1]
# start = [73729,43009,16769,1]
# start = [73729,44033,16385,1]
# start = [73729,44033,16513,1]
# start = [73729,44033,16641,1]
# start = [73729,44033,16769,1]
# start = [73729,45057,16513,1]
# start = [73729,45057,16641,1]
# start = [73729,45057,16769,1]
# start = [73729,46081,16513,1]
# start = [74753,13313,16897,1]
# start = [74753,14337,16513,1]
# start = [74753,14337,16769,1]
# start = [74753,15361,16513,1]
# start = [74753,15361,16641,1]
# start = [74753,15361,16769,1]
# start = [74753,15361,16897,1]
# start = [74753,16385,16385,1]
# start = [74753,16385,16513,1]
# start = [74753,16385,16641,1]
# start = [74753,16385,16769,1]
# start = [74753,16385,16897,1]
# start = [74753,17409,16385,1]
# start = [74753,17409,16513,1]
# start = [74753,17409,16641,1]
# start = [74753,17409,16769,1]
# start = [74753,17409,16897,1]
# start = [74753,18433,16385,1]
# start = [74753,18433,16513,1]
# start = [74753,18433,16641,1]
# start = [74753,18433,16769,1]
# start = [74753,19457,16385,1]
# start = [74753,19457,16513,1]
# start = [74753,19457,16641,1]
# start = [74753,19457,16769,1]
# start = [74753,19457,16897,1]
# start = [74753,20481,16385,1]
# start = [74753,20481,16513,1]
# start = [74753,20481,16641,1]
# start = [74753,20481,16769,1]
# start = [74753,20481,16897,1]
# start = [74753,21505,16385,1]
# start = [74753,21505,16513,1]
# start = [74753,21505,16641,1]
# start = [74753,21505,16769,1]
# start = [74753,22529,16385,1]
# start = [74753,22529,16513,1]
# start = [74753,22529,16641,1]
# start = [74753,22529,16769,1]
# start = [74753,22529,16897,1]
# start = [74753,23553,16385,1]
# start = [74753,23553,16513,1]
# start = [74753,23553,16769,1]
# start = [74753,24577,16385,1]
# start = [74753,24577,16513,1]
# start = [74753,24577,16641,1]
# start = [74753,24577,16769,1]
# start = [74753,25601,16385,1]
# start = [74753,25601,16513,1]
# start = [74753,25601,16641,1]
# start = [74753,25601,16769,1]
# start = [74753,26625,16385,1]
# start = [74753,26625,16513,1]
# start = [74753,26625,16769,1]
# start = [74753,27649,16385,1]
# start = [74753,27649,16513,1]
# start = [74753,27649,16769,1]
# start = [74753,28673,16385,1]
# start = [74753,28673,16513,1]
# start = [74753,28673,16641,1]
# start = [74753,28673,16769,1]
# start = [74753,29697,16385,1]
# start = [74753,29697,16513,1]
# start = [74753,29697,16641,1]
# start = [74753,29697,16769,1]
# start = [74753,30721,16385,1]
# start = [74753,30721,16641,1]
# start = [74753,30721,16769,1]
# start = [74753,31745,16385,1]
# start = [74753,31745,16513,1]
# start = [74753,31745,16769,1]
# start = [74753,32769,16385,1]
# start = [74753,32769,16513,1]
# start = [74753,32769,16769,1]
# start = [74753,33793,16385,1]
# start = [74753,33793,16513,1]
# start = [74753,33793,16769,1]
# start = [74753,34817,16385,1]
# start = [74753,34817,16513,1]
# start = [74753,34817,16769,1]
# start = [74753,35841,16385,1]
# start = [74753,35841,16513,1]
# start = [74753,35841,16641,1]
# start = [74753,35841,16769,1]
# start = [74753,36865,16385,1]
# start = [74753,36865,16513,1]
# start = [74753,36865,16641,1]
# start = [74753,36865,16769,1]
# start = [74753,37889,16385,1]
# start = [74753,37889,16641,1]
# start = [74753,37889,16769,1]
# start = [74753,38913,16385,1]
# start = [74753,38913,16513,1]
# start = [74753,38913,16641,1]
# start = [74753,38913,16769,1]
# start = [74753,39937,16385,1]
# start = [74753,39937,16513,1]
# start = [74753,39937,16641,1]
# start = [74753,39937,16769,1]
# start = [74753,40961,16385,1]
# start = [74753,40961,16513,1]
# start = [74753,40961,16641,1]
# start = [74753,40961,16769,1]
# start = [74753,41985,16385,1]
# start = [74753,41985,16513,1]
# start = [74753,41985,16641,1]
# start = [74753,41985,16769,1]
# start = [74753,43009,16385,1]
# start = [74753,43009,16513,1]
# start = [74753,43009,16641,1]
# start = [74753,43009,16769,1]
# start = [74753,44033,16385,1]
# start = [74753,44033,16513,1]
# start = [74753,44033,16641,1]
# start = [74753,44033,16769,1]
# start = [74753,45057,16513,1]
# start = [74753,45057,16641,1]
# start = [75777,12289,16897,1]
# start = [75777,14337,16769,1]
# start = [75777,14337,16897,1]
# start = [75777,15361,16769,1]
# start = [75777,15361,16897,1]
# start = [75777,16385,16513,1]
# start = [75777,16385,16641,1]
# start = [75777,16385,16769,1]
# start = [75777,17409,16513,1]
# start = [75777,17409,16769,1]
# start = [75777,17409,16897,1]
# start = [75777,18433,16513,1]
# start = [75777,18433,16769,1]
# start = [75777,19457,16513,1]
# start = [75777,19457,16769,1]
# start = [75777,20481,16513,1]
# start = [75777,20481,16769,1]
# start = [75777,21505,16513,1]
# start = [75777,21505,16641,1]
# start = [75777,21505,16769,1]
# start = [75777,21505,16897,1]
# start = [75777,22529,16513,1]
# start = [75777,22529,16641,1]
# start = [75777,22529,16769,1]
# start = [75777,23553,16513,1]
# start = [75777,23553,16769,1]
# start = [75777,24577,16513,1]
# start = [75777,24577,16641,1]
# start = [75777,24577,16769,1]
# start = [75777,24577,16897,1]
# start = [75777,25601,16513,1]
# start = [75777,25601,16641,1]
# start = [75777,25601,16769,1]
# start = [75777,26625,16513,1]
# start = [75777,26625,16641,1]
# start = [75777,26625,16769,1]
# start = [75777,26625,16897,1]
# start = [75777,27649,16513,1]
# start = [75777,27649,16641,1]
# start = [75777,27649,16769,1]
# start = [75777,28673,16513,1]
# start = [75777,28673,16641,1]
# start = [75777,28673,16769,1]
# start = [75777,28673,16897,1]
# start = [75777,29697,16513,1]
# start = [75777,29697,16641,1]
# start = [75777,29697,16769,1]
# start = [75777,30721,16513,1]
# start = [75777,30721,16641,1]
# start = [75777,30721,16769,1]
# start = [75777,31745,16641,1]
# start = [75777,31745,16769,1]
# start = [75777,32769,16513,1]
# start = [75777,32769,16641,1]
# start = [75777,32769,16769,1]
# start = [75777,33793,16513,1]
# start = [75777,33793,16641,1]
# start = [75777,33793,16769,1]
# start = [75777,34817,16513,1]
# start = [75777,34817,16641,1]
# start = [75777,34817,16769,1]
# start = [75777,35841,16513,1]
# start = [75777,35841,16641,1]
# start = [75777,35841,16769,1]
# start = [75777,36865,16513,1]
# start = [75777,36865,16641,1]
# start = [75777,36865,16769,1]
# start = [75777,37889,16769,1]
# start = [75777,38913,16513,1]
# start = [75777,38913,16641,1]
# start = [75777,38913,16769,1]
# start = [75777,39937,16641,1]
# start = [75777,39937,16769,1]
# start = [75777,40961,16641,1]
# start = [75777,40961,16769,1]
# start = [75777,41985,16641,1]
# start = [75777,41985,16769,1]
# start = [75777,43009,16641,1]
# start = [75777,43009,16769,1]
# start = [75777,44033,16641,1]
# start = [75777,44033,16769,1]
# start = [76801,14337,16897,1]
# start = [76801,15361,16897,1]
# start = [76801,16385,16897,1]
# start = [76801,17409,16897,1]
# start = [76801,18433,16897,1]
# start = [76801,19457,16897,1]
# start = [76801,22529,16897,1]
# start = [76801,23553,16897,1]
# start = [76801,24577,16897,1]
# start = [76801,28673,16897,1]
# start = [76801,41985,16769,1]
# start = [77825,12289,16897,1]
# start = [77825,13313,16897,1]
# start = [77825,14337,16897,1]
# start = [77825,15361,16897,1]
# start = [77825,16385,16897,1]
# start = [77825,18433,16897,1]
# start = [77825,21505,16897,1]
# start = [77825,25601,16897,1]
# start = [77825,27649,16897,1]
# start = [78849,12289,16897,1]
# start = [78849,13313,16897,1]
# start = [78849,15361,16897,1]
# start = [78849,16385,16897,1]
# start = [78849,18433,16897,1]
# start = [78849,19457,16897,1]
# start = [78849,20481,16897,1]
# start = [79873,12289,16897,1]
# start = [79873,13313,16897,1]
# start = [79873,14337,16897,1]
# start = [79873,15361,16897,1]
# start = [79873,16385,16897,1]
# start = [79873,17409,16897,1]
# start = [79873,19457,16897,1]
# start = [79873,21505,16897,1]
# start = [79873,23553,16897,1]
# start = [79873,26625,16897,1]
# start = [80897,12289,16897,1]
# start = [80897,13313,16897,1]
# start = [80897,14337,16897,1]
# start = [80897,15361,16897,1]
# start = [80897,16385,16897,1]
# start = [80897,17409,16897,1]
# start = [80897,18433,16897,1]
# start = [80897,19457,16897,1]
# CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((14337,12289,16385,1)),CartesianIndex{4}((81920,47104,17152,3)))

# %%
# vol = ba[10000:12000,10000:12000,500:600,1];
vol = ba[-100:200,-100:200,1:1200,1];
# vol = ba[21100:22200,31100:32200,1:1200,1];
# Out:
# H5SBIGARRAY_DIRECTORY = "/usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap"
# globalRange =
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,-100,1,1)),CartesianIndex{4}((0,0,128,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((924,924,1,1)),CartesianIndex{4}((1024,1024,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_-1023-0_1-128_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,1,1)),CartesianIndex{4}((101,101,128,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_-1023-0_1-128_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,-100,1,1)),CartesianIndex{4}((200,0,128,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,924,1,1)),CartesianIndex{4}((200,1024,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_-1023-0_1-128_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((102,1,1,1)),CartesianIndex{4}((301,101,128,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_-1023-0_1-128_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,1,1,1)),CartesianIndex{4}((0,200,128,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((924,1,1,1)),CartesianIndex{4}((1024,200,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_1-1024_1-128_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,102,1,1)),CartesianIndex{4}((101,301,128,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_1-1024_1-128_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,1,1)),CartesianIndex{4}((200,200,128,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,1,1)),CartesianIndex{4}((200,200,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_1-1024_1-128_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((102,102,1,1)),CartesianIndex{4}((301,301,128,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_1-1024_1-128_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,-100,129,1)),CartesianIndex{4}((0,0,256,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((924,924,1,1)),CartesianIndex{4}((1024,1024,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_-1023-0_129-256_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,129,1)),CartesianIndex{4}((101,101,256,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_-1023-0_129-256_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,-100,129,1)),CartesianIndex{4}((200,0,256,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,924,1,1)),CartesianIndex{4}((200,1024,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_-1023-0_129-256_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((102,1,129,1)),CartesianIndex{4}((301,101,256,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_-1023-0_129-256_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,1,129,1)),CartesianIndex{4}((0,200,256,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((924,1,1,1)),CartesianIndex{4}((1024,200,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_1-1024_129-256_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,102,129,1)),CartesianIndex{4}((101,301,256,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_1-1024_129-256_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,129,1)),CartesianIndex{4}((200,200,256,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,1,1)),CartesianIndex{4}((200,200,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_1-1024_129-256_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((102,102,129,1)),CartesianIndex{4}((301,301,256,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_1-1024_129-256_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,-100,257,1)),CartesianIndex{4}((0,0,384,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((924,924,1,1)),CartesianIndex{4}((1024,1024,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_-1023-0_257-384_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,257,1)),CartesianIndex{4}((101,101,384,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_-1023-0_257-384_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,-100,257,1)),CartesianIndex{4}((200,0,384,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,924,1,1)),CartesianIndex{4}((200,1024,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_-1023-0_257-384_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((102,1,257,1)),CartesianIndex{4}((301,101,384,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_-1023-0_257-384_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,1,257,1)),CartesianIndex{4}((0,200,384,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((924,1,1,1)),CartesianIndex{4}((1024,200,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_1-1024_257-384_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,102,257,1)),CartesianIndex{4}((101,301,384,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_1-1024_257-384_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,257,1)),CartesianIndex{4}((200,200,384,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,1,1)),CartesianIndex{4}((200,200,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_1-1024_257-384_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((102,102,257,1)),CartesianIndex{4}((301,301,384,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_1-1024_257-384_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,-100,385,1)),CartesianIndex{4}((0,0,512,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((924,924,1,1)),CartesianIndex{4}((1024,1024,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_-1023-0_385-512_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,385,1)),CartesianIndex{4}((101,101,512,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_-1023-0_385-512_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,-100,385,1)),CartesianIndex{4}((200,0,512,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,924,1,1)),CartesianIndex{4}((200,1024,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_-1023-0_385-512_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((102,1,385,1)),CartesianIndex{4}((301,101,512,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_-1023-0_385-512_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,1,385,1)),CartesianIndex{4}((0,200,512,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((924,1,1,1)),CartesianIndex{4}((1024,200,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_1-1024_385-512_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,102,385,1)),CartesianIndex{4}((101,301,512,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_1-1024_385-512_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,385,1)),CartesianIndex{4}((200,200,512,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,1,1)),CartesianIndex{4}((200,200,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_1-1024_385-512_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((102,102,385,1)),CartesianIndex{4}((301,301,512,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_1-1024_385-512_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,-100,513,1)),CartesianIndex{4}((0,0,640,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((924,924,1,1)),CartesianIndex{4}((1024,1024,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_-1023-0_513-640_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,513,1)),CartesianIndex{4}((101,101,640,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_-1023-0_513-640_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,-100,513,1)),CartesianIndex{4}((200,0,640,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,924,1,1)),CartesianIndex{4}((200,1024,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_-1023-0_513-640_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((102,1,513,1)),CartesianIndex{4}((301,101,640,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_-1023-0_513-640_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,1,513,1)),CartesianIndex{4}((0,200,640,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((924,1,1,1)),CartesianIndex{4}((1024,200,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_1-1024_513-640_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,102,513,1)),CartesianIndex{4}((101,301,640,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_1-1024_513-640_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,513,1)),CartesianIndex{4}((200,200,640,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,1,1)),CartesianIndex{4}((200,200,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_1-1024_513-640_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((102,102,513,1)),CartesianIndex{4}((301,301,640,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_1-1024_513-640_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,-100,641,1)),CartesianIndex{4}((0,0,768,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((924,924,1,1)),CartesianIndex{4}((1024,1024,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_-1023-0_641-768_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,641,1)),CartesianIndex{4}((101,101,768,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_-1023-0_641-768_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,-100,641,1)),CartesianIndex{4}((200,0,768,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,924,1,1)),CartesianIndex{4}((200,1024,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_-1023-0_641-768_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((102,1,641,1)),CartesianIndex{4}((301,101,768,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_-1023-0_641-768_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,1,641,1)),CartesianIndex{4}((0,200,768,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((924,1,1,1)),CartesianIndex{4}((1024,200,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_1-1024_641-768_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,102,641,1)),CartesianIndex{4}((101,301,768,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_1-1024_641-768_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,641,1)),CartesianIndex{4}((200,200,768,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,1,1)),CartesianIndex{4}((200,200,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_1-1024_641-768_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((102,102,641,1)),CartesianIndex{4}((301,301,768,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_1-1024_641-768_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,-100,769,1)),CartesianIndex{4}((0,0,896,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((924,924,1,1)),CartesianIndex{4}((1024,1024,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_-1023-0_769-896_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,769,1)),CartesianIndex{4}((101,101,896,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_-1023-0_769-896_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,-100,769,1)),CartesianIndex{4}((200,0,896,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,924,1,1)),CartesianIndex{4}((200,1024,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_-1023-0_769-896_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((102,1,769,1)),CartesianIndex{4}((301,101,896,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_-1023-0_769-896_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,1,769,1)),CartesianIndex{4}((0,200,896,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((924,1,1,1)),CartesianIndex{4}((1024,200,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_1-1024_769-896_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,102,769,1)),CartesianIndex{4}((101,301,896,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_1-1024_769-896_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,769,1)),CartesianIndex{4}((200,200,896,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,1,1)),CartesianIndex{4}((200,200,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_1-1024_769-896_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((102,102,769,1)),CartesianIndex{4}((301,301,896,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_1-1024_769-896_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,-100,897,1)),CartesianIndex{4}((0,0,1024,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((924,924,1,1)),CartesianIndex{4}((1024,1024,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_-1023-0_897-1024_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,897,1)),CartesianIndex{4}((101,101,1024,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_-1023-0_897-1024_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,-100,897,1)),CartesianIndex{4}((200,0,1024,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,924,1,1)),CartesianIndex{4}((200,1024,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_-1023-0_897-1024_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((102,1,897,1)),CartesianIndex{4}((301,101,1024,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_-1023-0_897-1024_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,1,897,1)),CartesianIndex{4}((0,200,1024,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((924,1,1,1)),CartesianIndex{4}((1024,200,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_1-1024_897-1024_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,102,897,1)),CartesianIndex{4}((101,301,1024,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_1-1024_897-1024_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,897,1)),CartesianIndex{4}((200,200,1024,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,1,1)),CartesianIndex{4}((200,200,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_1-1024_897-1024_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((102,102,897,1)),CartesianIndex{4}((301,301,1024,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_1-1024_897-1024_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,-100,1025,1)),CartesianIndex{4}((0,0,1152,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((924,924,1,1)),CartesianIndex{4}((1024,1024,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_-1023-0_1025-1152_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,1025,1)),CartesianIndex{4}((101,101,1152,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_-1023-0_1025-1152_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,-100,1025,1)),CartesianIndex{4}((200,0,1152,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,924,1,1)),CartesianIndex{4}((200,1024,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_-1023-0_1025-1152_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((102,1,1025,1)),CartesianIndex{4}((301,101,1152,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_-1023-0_1025-1152_1-3.h5
# CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,-100,1,1)),CartesianIndex{4}((0,0,128,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,-100,1,1)),CartesianIndex{4}((200,0,128,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,1,1,1)),CartesianIndex{4}((0,200,128,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,1,1)),CartesianIndex{4}((200,200,128,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,-100,129,1)),CartesianIndex{4}((0,0,256,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,-100,129,1)),CartesianIndex{4}((200,0,256,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,1,129,1)),CartesianIndex{4}((0,200,256,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,129,1)),CartesianIndex{4}((200,200,256,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,-100,257,1)),CartesianIndex{4}((0,0,384,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,-100,257,1)),CartesianIndex{4}((200,0,384,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,1,257,1)),CartesianIndex{4}((0,200,384,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,257,1)),CartesianIndex{4}((200,200,384,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,-100,385,1)),CartesianIndex{4}((0,0,512,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,-100,385,1)),CartesianIndex{4}((200,0,512,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,1,385,1)),CartesianIndex{4}((0,200,512,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,385,1)),CartesianIndex{4}((200,200,512,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,-100,513,1)),CartesianIndex{4}((0,0,640,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,-100,513,1)),CartesianIndex{4}((200,0,640,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,1,513,1)),CartesianIndex{4}((0,200,640,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,513,1)),CartesianIndex{4}((200,200,640,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,-100,641,1)),CartesianIndex{4}((0,0,768,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,-100,641,1)),CartesianIndex{4}((200,0,768,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,1,641,1)),CartesianIndex{4}((0,200,768,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,641,1)),CartesianIndex{4}((200,200,768,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,-100,769,1)),CartesianIndex{4}((0,0,896,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,-100,769,1)),CartesianIndex{4}((200,0,896,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,1,769,1)),CartesianIndex{4}((0,200,896,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,769,1)),CartesianIndex{4}((200,200,896,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,-100,897,1)),CartesianIndex{4}((0,0,1024,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,-100,897,1)),CartesianIndex{4}((200,0,1024,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,1,897,1)),CartesianIndex{4}((0,200,1024,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,897,1)),CartesianIndex{4}((200,200,1024,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,-100,1025,1)),CartesianIndex{4}((0,0,1152,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,-100,1025,1)),CartesianIndex{4}((200,0,1152,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,1,1025,1)),CartesianIndex{4}((0,200,1152,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,1025,1)),CartesianIndex{4}((200,200,1152,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,-100,1153,1)),CartesianIndex{4}((0,0,1200,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,-100,1153,1)),CartesianIndex{4}((200,0,1200,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,1,1153,1)),CartesianIndex{4}((0,200,1200,1)))
# globalRange = CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,1153,1)),CartesianIndex{4}((200,200,1200,1)))
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,1,1025,1)),CartesianIndex{4}((0,200,1152,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((924,1,1,1)),CartesianIndex{4}((1024,200,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_1-1024_1025-1152_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,102,1025,1)),CartesianIndex{4}((101,301,1152,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_1-1024_1025-1152_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,1025,1)),CartesianIndex{4}((200,200,1152,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,1,1)),CartesianIndex{4}((200,200,128,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_1-1024_1025-1152_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((102,102,1025,1)),CartesianIndex{4}((301,301,1152,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_1-1024_1025-1152_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,-100,1153,1)),CartesianIndex{4}((0,0,1200,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((924,924,1,1)),CartesianIndex{4}((1024,1024,48,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_-1023-0_1153-1280_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,1153,1)),CartesianIndex{4}((101,101,1200,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_-1023-0_1153-1280_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,-100,1153,1)),CartesianIndex{4}((200,0,1200,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,924,1,1)),CartesianIndex{4}((200,1024,48,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_-1023-0_1153-1280_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((102,1,1153,1)),CartesianIndex{4}((301,101,1200,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_-1023-0_1153-1280_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((-100,1,1153,1)),CartesianIndex{4}((0,200,1200,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((924,1,1,1)),CartesianIndex{4}((1024,200,48,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_1-1024_1153-1280_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,102,1153,1)),CartesianIndex{4}((101,301,1200,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_-1023-0_1-1024_1153-1280_1-3.h5
# INFO: read CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,1153,1)),CartesianIndex{4}((200,200,1200,1))) from CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((1,1,1,1)),CartesianIndex{4}((200,200,48,1))) of /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_1-1024_1153-1280_1-3.h5 to buffer CartesianRange{CartesianIndex{4}}(CartesianIndex{4}((102,102,1153,1)),CartesianIndex{4}((301,301,1200,1))) ...
# WARNING: filled with zeros because file do not exist: /usr/people/jingpeng/seungmount/research/Jingpeng/14_zfish/jknet/4x4x4/affinitymap/block_1-1024_1-1024_1153-1280_1-3.h5

# %%
using Images
using Interact
# vol = ba[1000:2000,1000:2000,100:200,1]
@manipulate for z = 1:size(vol,3)
    img = Image(vol[:,:,z,1], colorspace="Gray", spatialorder=["x","y"])
end
# Out:
# Interact.Slider{Int64}(Signal{Int64}(600, nactions=0),"z",600,1:1200,true)
# Gray Images.Image with:
#   data: 301×301 Array{Float32,2}
#   properties:
#     colorspace: Gray
#     spatialorder:  x y
